# %% [markdown]
# # Preprocessing, GridSearch and Training SpiderNet-8 on Private Data

# %%
import numpy as np
from numpy import array
import pandas as pd

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

import math

import matplotlib.pylab as plt
from matplotlib.pyplot import cm
import seaborn as sns
import itertools
import collections
from collections import OrderedDict, Counter

import scipy.stats as stats
from scipy.stats import normaltest, kstest, ttest_ind, ttest_rel, mannwhitneyu, wilcoxon, levene, bartlett
from scipy.stats import chi2_contingency, fisher_exact, mode, pearsonr, f_oneway, kruskal, spearmanr

from rfpimp import *

from datetime import datetime
import re
from seaborn import heatmap
import random
import statsmodels.distributions.empirical_distribution as edf
from scipy.interpolate import interp1d

from sklearn.utils import resample
from functools import reduce
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score

from sklearn import metrics, preprocessing
from sklearn.metrics import roc_auc_score, average_precision_score, f1_score, log_loss, recall_score
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler, PowerTransformer

from sklearn.utils import check_consistent_length, column_or_1d, assert_all_finite
from sklearn.utils.extmath import stable_cumsum
from sklearn.utils.multiclass import type_of_target
from sklearn.linear_model import LogisticRegression
import re
import gc
import os

from statsmodels.stats.proportion import proportions_ztest

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
import pathlib
import psutil
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.ensemble.forest module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
PATH_DATA = 'D:/Share/01 -Risk Desc Science/AntiFraud/Data Sets/'
PATH = 'D:/Share/safanasev/Python-notebook/AF_ML_v2_2014_2019/'
print(PATH_DATA)
print(PATH)
# Out:
# D:/Share/01 -Risk Desc Science/AntiFraud/Data Sets/
# D:/Share/safanasev/Python-notebook/AF_ML_v2_2014_2019/

# %%
task = 'binary'
missing_strings = 'MISSING'
p_value = 0.05
target_dict = {'good': 0, 'bad': 1}

# %%
target = 'BAD_FLAG'
index_month = 'MONTH_YEAR'
list_of_vars_for_strat = ['MONTH_YEAR']
sort_by_var = 'APPPOSID'

necessary_fields = [target, index_month, sort_by_var]

COL_DEL = ['Unnamed: 0', 'PERIOD_7', 'LOSS_90P']
COL_DEL = [x.upper() for x in COL_DEL]
COL_TRG = target

# %%
COL_DEL
# Out:
# ['UNNAMED: 0', 'PERIOD_7', 'LOSS_90P']

# %%
necessary_fields
# Out:
# ['BAD_FLAG', 'MONTH_YEAR', 'APPPOSID']

# %% [markdown]
# ## Loading preprocessing data

# %%
PATH
# Out:
# 'D:/Share/safanasev/Python-notebook/AF_ML_v2_2014_2019/'

# %%
train_for = pd.read_csv(PATH + 'train_163_prep.csv')
valid_for = pd.read_csv(PATH + 'valid_163_prep.csv')
test_for = pd.read_csv(PATH + 'test_163_prep.csv')

# %%
PATH + 'train_163_prep.csv', PATH + 'test_163_prep.csv'
# Out:
# ('D:/Share/safanasev/Python-notebook/AF_ML_v2_2014_2019/train_163_prep.csv',
#  'D:/Share/safanasev/Python-notebook/AF_ML_v2_2014_2019/test_163_prep.csv')

# %%
y_train = train_for[target]
y_test = valid_for[target]
y_val = test_for[target]

train_for.drop('Unnamed: 0', axis=1, inplace=True)
valid_for.drop('Unnamed: 0', axis=1, inplace=True)
test_for.drop('Unnamed: 0', axis=1, inplace=True)


col = train_for.columns.to_list()
col.remove(target)


X_1_2 = train_for[col]
X_2_2 = valid_for[col]
X_3_2 = test_for[col]

# %%
x_col = X_2_2.columns
y_col = 'BAD_FLAG'

# %%
from keras.utils import np_utils

# %%
Y_test_2 = np_utils.to_categorical( y_test, 2)

# %%
#check correctness
X_1_2.shape,  X_2_2.shape, Y_test_2.shape
# Out:
# ((1507599, 163), (185400, 163), (185400, 2))

# %% [markdown]
# ## Loading public preprocessing data

# %%
target = 'LABEL'
index_month = 'MONTH'
list_of_vars_for_strat = ['MONTH']
sort_by_var = 'ID'

necessary_fields = [target, index_month, sort_by_var]

COL_DEL = ['Unnamed: 0'] 
COL_DEL = [x.upper() for x in COL_DEL]
COL_TRG = target

# %%
PATH = 'D:/Share/safanasev/Python-notebook/AF_ML_chinese/'
train_for = pd.read_csv(PATH + 'china_train_128_prep.csv')
valid_for = pd.read_csv(PATH + 'china_val_128_prep.csv')
test_for = pd.read_csv(PATH + 'china_test_128_prep.csv')

# %%
y_train = train_for[target]
y_val = valid_for[target]
y_test = test_for[target]

train_for.drop('Unnamed: 0', axis = 1, inplace = True)
valid_for.drop('Unnamed: 0', axis = 1, inplace = True)
test_for.drop('Unnamed: 0', axis = 1, inplace = True)


col = train_for.columns.to_list()
col.remove(target)


X_1_2 = train_for[col]
X_2_2 = valid_for[col]
X_3_2 = test_for[col]

# %%
x_col = X_2_2.columns
y_col = 'LABEL'

# %% [markdown]
# ## Loading tensorflow

# %%
from tensorflow.keras.layers import (
    Input, Activation, Dense, Flatten, Dropout)
from tensorflow.keras.layers import (Conv1D, MaxPooling1D, AveragePooling1D)
from tensorflow.keras.layers import add
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K

# %%
from tensorflow.keras.layers import ReLU, Concatenate, GlobalAveragePooling1D

# %%
from keras.utils import np_utils
from tensorflow.keras.models import Model

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.3.0

# %%
from tensorflow.keras.callbacks import EarlyStopping, Callback, LearningRateScheduler


class E_time(Callback):
    def on_train_begin(self, logs={}):
        tm = datetime.strftime(datetime.now(), "%d.%m.%Y %H:%M:%S")
        print('train_begin', '| time: ', tm)

    def on_epoch_end(self, epoch, logs={}):
        tm = datetime.strftime(datetime.now(), "%d.%m.%Y %H:%M:%S")
        print('epoch_end', '| time: ', tm)

        return


_time = E_time()

# %%
# DataGenerator is used to adjust the bad rate in each batch

class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self,  dataset, x_col, y_col,  batch_size=256, num_classes=2, alpha=0.1, random_state=42,
                 shuffle=True, class_w=None):
        self.batch_size = batch_size
        self.dataset = dataset
        self.x_col = x_col
        self.y_col = y_col
        self.indices = self.dataset.index.tolist()
        self.num_classes = num_classes
        self.shuffle = shuffle
        self.alpha = alpha
        self.random_state = random_state
        self.class_w = class_w
        self.on_epoch_end()

    def __len__(self):
        return math.ceil(len(self.indices) / self.batch_size)

    def __getitem__(self, index):
        index = self.index[index *
                           self.batch_size:(index + 1) * self.batch_size]
        batch = [self.indices[k] for k in index]

        data_tmp = self.dataset.loc[batch]
        data_tmp_b = data_tmp[data_tmp[self.y_col] == 1]
        data_tmp_b_all = self.dataset[self.dataset[self.y_col] == 1]
        X_tmp = data_tmp.head(0)

        if (self.alpha is None) and (self.class_w is None):
            X = data_tmp[self.x_col]
            y = data_tmp[self.y_col]

        elif (self.alpha is None) and self.class_w > 0:
            k = (self.class_w*self.batch_size)/(1-self.class_w)
            k = k - data_tmp_b.shape[0]
            if int(k) < 1:
                k = k+1
            ix2 = np.random.RandomState(
                self.random_state + int(k)).choice(data_tmp_b_all.shape[0], int(k))
            X_tmp = data_tmp_b_all.iloc[ix2]
            data_tmp = data_tmp.append(X_tmp, ignore_index=True)
            X = data_tmp[self.x_col]
            y = data_tmp[self.y_col]

        else:
            if data_tmp_b.shape[0] > 0:
                k = (self.alpha*self.batch_size /
                     data_tmp_b.shape[0] - 1)/(1-self.alpha)
                for i in range(0, int(k)):
                    X_tmp = X_tmp.append(data_tmp_b, ignore_index=True)
            else:
                k = (self.alpha*self.batch_size)/(1-self.alpha)
                ix2 = np.random.RandomState(
                    self.random_state + int(k)).choice(data_tmp_b_all.shape[0], int(k))
                X_tmp = data_tmp_b_all.iloc[ix2]
                data_tmp_b = X_tmp

            k_fraction = k - int(k)
            n_samples = int(round(data_tmp_b.shape[0]*k_fraction))

            ix = np.random.RandomState(self.random_state).choice(
                data_tmp_b.shape[0], n_samples)
            data_add_fraction = data_tmp_b.iloc[ix]
            X_tmp.append(data_add_fraction, ignore_index=True)

            data_tmp = data_tmp.append(X_tmp, ignore_index=True)

            X = data_tmp[self.x_col]
            y = data_tmp[self.y_col]

        if self.num_classes > 1:
            y = np_utils.to_categorical(y, self.num_classes)

        return [np.array(X)], np.array(y)

    def on_epoch_end(self):
        self.index = np.arange(len(self.indices))
        if self.shuffle == True:
            np.random.shuffle(self.index)

# %%
class Metrics(tf.keras.callbacks.Callback):
    def __init__(self, valid_data):
        super(Metrics, self).__init__()
        self.validation_data = valid_data

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        val_predict = self.model.predict(self.validation_data[0])[:, 1]
        val_targ = self.validation_data[1]
        
        if len(val_targ.shape) == 2: #and val_targ.shape[1] != 1:
            val_targ = val_targ[:,1]

        _val_aps = metrics.average_precision_score(val_targ, val_predict)
        #_val_recall = metrics.recall_score(val_targ, val_predict)
        _val_a = metrics.roc_auc_score(val_targ, val_predict)

        logs['val_aps'] = _val_aps
        logs['val_a'] = _val_a
        print(" — val_aps:  %f — val_a: %f" % (_val_aps, _val_a))
        return

# %%
# Seed value
import tensorflow as tf
import numpy as np
import random
import os
seed_value = 29

# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
os.environ['PYTHONHASHSEED'] = str(seed_value)

# 2. Set `python` built-in pseudo-random generator at a fixed value
random.seed(seed_value)

# 3. Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)

# 4. Set the `tensorflow` pseudo-random generator at a fixed value
tf.compat.v1.set_random_seed(seed_value)


# 5. Configure a new global `tensorflow` session
session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(
    graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)

# %% [markdown]
# ## SpiderNet-6

# %%
from tensorflow.keras.layers import GlobalMaxPooling1D

# %%
def max_pool(min_pool, n_pool, padding_pool, str_pool, y):
    if y.shape[1] < (min_pool):

        return MaxPooling1D(pool_size=n_pool, padding=padding_pool, strides=1)(y)
    else:
        return MaxPooling1D(pool_size=n_pool, padding=padding_pool, strides=str_pool)(y)

# %%
def spider_model(l2_conv=None, reg=1E-5,
                 _bias=True,  n_features=163, n_pool=2, n_kernel=5, n_filters=5, n_strides=1,
                 classes=2, hidden=64, drop_out=0.25, drop_out_conv=0.001, drop_out_rate=4,
                 padding_pool='valid',
                 gl_pool_max=False):

    if reg == None:
        l2_batch_gamma = None
        l2_batch_betta = None
    else:
        l2_batch_gamma = l2(reg)
        l2_batch_betta = l2(reg)

    x = Input(shape=(n_features, 1))
    n = 0
    y = Conv1D(filters=n_filters, kernel_size=n_kernel, strides=n_strides, padding='same',
               use_bias=_bias, kernel_regularizer=l2_conv)(x)

    y = BatchNormalization(gamma_regularizer=l2_batch_gamma,
                           beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)

    y = MaxPooling1D(pool_size=n_pool, padding=padding_pool)(y)
    shortcut1_2 = MaxPooling1D(
        pool_size=n_pool, padding=padding_pool)(y)  # поправить
    shortcut1_3 = MaxPooling1D(
        pool_size=n_pool, padding=padding_pool)(shortcut1_2)
    shortcut1_4 = MaxPooling1D(
        pool_size=n_pool, padding=padding_pool)(shortcut1_3)
    shortcut1_5 = MaxPooling1D(
        pool_size=n_pool, padding=padding_pool)(shortcut1_4)

    # второй spider-block
    y = Conv1D(filters=n_filters*2, kernel_size=n_kernel, strides=n_strides, padding='same',
               use_bias=_bias, kernel_regularizer=l2_conv)(y)
    y = BatchNormalization(gamma_regularizer=l2_batch_gamma,
                           beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)

    y = MaxPooling1D(pool_size=n_pool, padding=padding_pool)(y)
    shortcut2_2 = MaxPooling1D(pool_size=n_pool, padding=padding_pool)(y)
    shortcut2_3 = MaxPooling1D(
        pool_size=n_pool, padding=padding_pool)(shortcut2_2)
    shortcut2_4 = MaxPooling1D(
        pool_size=n_pool, padding=padding_pool)(shortcut2_3)

    y = Concatenate(axis=-1)([shortcut1_2, y])
    n = n+1

    # третий spider-block
    y = Conv1D(filters=n_filters*(3 + 1), kernel_size=n_kernel, strides=n_strides, padding='same',
               use_bias=_bias, kernel_regularizer=l2_conv)(y)
    y = BatchNormalization(gamma_regularizer=l2_batch_gamma,
                           beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)

    y = MaxPooling1D(pool_size=n_pool, padding=padding_pool)(y)
    shortcut3_2 = MaxPooling1D(pool_size=n_pool, padding=padding_pool)(y)
    shortcut3_3 = MaxPooling1D(
        pool_size=n_pool, padding=padding_pool)(shortcut3_2)

    y = Concatenate(axis=-1)([shortcut2_2, shortcut1_3, y])
    n = n+1
    # четвертый spider-block
    y = Conv1D(filters=n_filters*(4 + 1), kernel_size=n_kernel, strides=n_strides, padding='same',
               use_bias=_bias, kernel_regularizer=l2_conv)(y)
    y = BatchNormalization(gamma_regularizer=l2_batch_gamma,
                           beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)

    y = MaxPooling1D(pool_size=n_pool, padding=padding_pool)(y)
    shortcut4_2 = MaxPooling1D(pool_size=n_pool, padding=padding_pool)(y)

    y = Concatenate(axis=-1)([shortcut3_2, shortcut2_3, shortcut1_4, y])
    n = n+1
    if drop_out_rate is not None:
        y = Dropout(drop_out_conv*(n**drop_out_rate))(y)
        print(n, drop_out_conv*(n**drop_out_rate))
    else:
        print('without dropout conv')

    # пятый spider-block
    y = Conv1D(filters=n_filters*(5 + 1), kernel_size=n_kernel, strides=n_strides, padding='same',
               use_bias=_bias, kernel_regularizer=l2_conv)(y)
    y = BatchNormalization(gamma_regularizer=l2_batch_gamma,
                           beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)

    y = MaxPooling1D(pool_size=n_pool, padding=padding_pool)(y)
    y = Concatenate(
        axis=-1)([shortcut4_2, shortcut3_3, shortcut2_4, shortcut1_5, y])
    n = n+1
    if drop_out_rate is not None:
        y = Dropout(drop_out_conv*(n**drop_out_rate))(y)
        print(n, drop_out_conv*(n**drop_out_rate))
    else:
        print('without dropout conv')

    # шестой spider-block
    y = Conv1D(filters=n_filters*(6 + 1), kernel_size=n_kernel, strides=n_strides, padding='same',
               use_bias=_bias, kernel_regularizer=l2_conv)(y)
    y = BatchNormalization(gamma_regularizer=l2_batch_gamma,
                           beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)
    if gl_pool_max:
        z = GlobalMaxPooling1D()(y)

    else:
        z = GlobalAveragePooling1D()(y)

    z = Dense(hidden, activation='relu')(z)
    z = Dropout(drop_out)(z)
    z = Dense(hidden, activation='relu')(z)
    z = Dropout(drop_out)(z)
    predictions = Dense(classes, activation='softmax')(z)

    model_15 = Model(inputs=x, outputs=predictions)

    return model_15

# %%
def spider_model_8block(l2_conv = None, reg = 1E-5 , reg_dense = 1E-5,
                 _bias = True,  n_features = 163, n_pool = 2, n_kernel = 5, n_filters = 5, n_strides = 1,
                 classes = 2, hidden = 64 , drop_out = 0.25, drop_out_conv = 0.001, drop_out_rate = 4 ,
                 padding_pool = 'valid' ,
                gl_pool_max = False,
                       min_pool = 12, str_pool = None):
    
    if reg == None:
        l2_batch_gamma = None 
        l2_batch_betta = None
    else:
        l2_batch_gamma = l2(reg)
        l2_batch_betta =l2(reg)
    
    if reg_dense == None:
        kernel_regularizer = None
    else:
        kernel_regularizer = l2(reg)   
    
    
    x = Input(shape=(  n_features, 1))
    n = -2 # для 6 - n = 0, для 8 = -2
    y = Conv1D(filters=n_filters, kernel_size=n_kernel, strides=n_strides, padding='same', 
           use_bias=_bias, kernel_regularizer=l2_conv)(x) 

    y = BatchNormalization(gamma_regularizer=l2_batch_gamma ,beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)
#y = Dropout(rate=drop_rate)(y)

    y = max_pool(min_pool, n_pool, padding_pool, str_pool, y) ##
    shortcut1_2 = max_pool(min_pool, n_pool, padding_pool, str_pool, y)## поправить
    shortcut1_3 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut1_2)##
    shortcut1_4 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut1_3)##
    
    shortcut1_5 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut1_4)
    shortcut1_6 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut1_5) #*
    shortcut1_7 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut1_6) #*

    # второй spider-block
    y = Conv1D(filters=n_filters*2, kernel_size=n_kernel, strides=n_strides, padding='same',
              use_bias=_bias, kernel_regularizer=l2_conv)(y) 
    y = BatchNormalization(gamma_regularizer=l2_batch_gamma ,beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)

    y = max_pool(min_pool, n_pool, padding_pool, str_pool, y) ##
    shortcut2_3 = max_pool(min_pool, n_pool, padding_pool, str_pool, y)##
    shortcut2_4 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut2_3)##
    
    shortcut2_5 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut2_4)
    shortcut2_6 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut2_5)
    shortcut2_7 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut2_6)


    y= Concatenate(axis=-1)([shortcut1_2, y])
    n = n+1

    # третий spider-block
    y = Conv1D(filters=n_filters*(3 + 1), kernel_size=n_kernel, strides=n_strides, padding='same',
              use_bias=_bias, kernel_regularizer=l2_conv)(y) 
    y = BatchNormalization(gamma_regularizer=l2_batch_gamma ,beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)

    y = max_pool(min_pool, n_pool, padding_pool, str_pool, y) ##
    shortcut3_4 = max_pool(min_pool, n_pool, padding_pool, str_pool, y)##
    
    shortcut3_5 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut3_4)##
    shortcut3_6 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut3_5)##
    shortcut3_7 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut3_6)##

    y= Concatenate(axis=-1)([shortcut2_3, shortcut1_3, y])
    
    n = n+1
    # четвертый spider-block
    y = Conv1D(filters=n_filters*(4 + 1), kernel_size=n_kernel, strides=n_strides, padding='same',
              use_bias=_bias, kernel_regularizer=l2_conv)(y) 
    y = BatchNormalization(gamma_regularizer=l2_batch_gamma ,beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)

    y = max_pool(min_pool, n_pool, padding_pool, str_pool, y) ##
    shortcut4_5 = max_pool(min_pool, n_pool, padding_pool, str_pool, y)##
    shortcut4_6 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut4_5)##
    shortcut4_7 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut4_6)##

    y= Concatenate(axis=-1)([shortcut3_4, shortcut2_4, shortcut1_4, y])
    n = n+1
    if drop_out_rate is not None:
        y = Dropout(drop_out_conv*(n**drop_out_rate))(y)
        print(n, drop_out_conv*(n**drop_out_rate))
    else:
        print('without dropout conv')

    # пятый spider-block
    y = Conv1D(filters=n_filters*(5 + 1), kernel_size=n_kernel, strides=n_strides, padding='same',
              use_bias=_bias, kernel_regularizer=l2_conv)(y) 
    y = BatchNormalization(gamma_regularizer=l2_batch_gamma ,beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)

    y = max_pool(min_pool, n_pool, padding_pool, str_pool, y) ##
    shortcut5_6 = max_pool(min_pool, n_pool, padding_pool, str_pool, y)
    shortcut5_7 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut5_6)    
    
    
    y= Concatenate(axis=-1)([shortcut4_5, shortcut3_5, shortcut2_5, shortcut1_5, y])
    n = n+1
    if drop_out_rate is not None:
        y = Dropout(drop_out_conv*(n**drop_out_rate))(y)
        print(n, drop_out_conv*(n**drop_out_rate))
    else:
        print('without dropout conv')

    # шестой spider-block
    y = Conv1D(filters=n_filters*(6 + 1), kernel_size=n_kernel, strides=n_strides, padding='same',
              use_bias=_bias, kernel_regularizer=l2_conv)(y) 
    y = BatchNormalization(gamma_regularizer=l2_batch_gamma ,beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)
    
    y = max_pool(min_pool, n_pool, padding_pool, str_pool, y) ##
    shortcut6_7 = max_pool(min_pool, n_pool, padding_pool, str_pool, y)
    
    y= Concatenate(axis=-1)([shortcut5_6, shortcut4_6, shortcut3_6, shortcut2_6, shortcut1_6, y])
    n = n+1
    if drop_out_rate is not None:
        y = Dropout(drop_out_conv*(n**drop_out_rate))(y)
        print(n, drop_out_conv*(n**drop_out_rate))
    else:
        print('without dropout conv')
    
    
    # седьмой блок
    y = Conv1D(filters=n_filters*(7 + 1), kernel_size=n_kernel, strides=n_strides, padding='same',
              use_bias=_bias, kernel_regularizer=l2_conv)(y) 
    y = BatchNormalization(gamma_regularizer=l2_batch_gamma ,beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)
    
    y = max_pool(min_pool, n_pool, padding_pool, str_pool, y) ##
    
    y= Concatenate(axis=-1)([shortcut6_7, shortcut5_7, shortcut4_7, shortcut3_7, shortcut2_7, shortcut1_7, y])
    n = n+1
    if drop_out_rate is not None:
        y = Dropout(drop_out_conv*(n**drop_out_rate))(y)
        print(n, drop_out_conv*(n**drop_out_rate))
    else:
        print('without dropout conv')
            
    
     # восьмой блок
    y = Conv1D(filters=n_filters*(8 + 1), kernel_size=n_kernel, strides=n_strides, padding='same',
              use_bias=_bias, kernel_regularizer=l2_conv)(y) 
    y = BatchNormalization(gamma_regularizer=l2_batch_gamma ,beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)
    
    y = max_pool(min_pool, n_pool, padding_pool, str_pool, y) ##
    
    if gl_pool_max:
        z = GlobalMaxPooling1D()(y)
        
    else:
        z = GlobalAveragePooling1D()(y)
    #z = Flatten()(y) #сглаживание, пример использования - https://stackoverflow.com/questions/43237124/what-is-the-role-of-flatten-in-keras
    z = Dense(hidden, activation='relu', kernel_regularizer = kernel_regularizer)(z)
    z = Dropout(drop_out)(z)
    z = Dense(hidden, activation='relu', kernel_regularizer = kernel_regularizer)(z)
    z = Dropout(drop_out)(z)
    predictions = Dense(classes, activation='softmax')(z)

    #model = Sequential()
    model_15 = Model(inputs=x, outputs=predictions)
    
    return model_15

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:\\Program Files (x86)\\Graphviz2.38\\bin\\'

# %%
# Сomputational graph for Spider - 6
model_15 = spider_model_8block(drop_out_conv=None, drop_out_rate=None)
tf.keras.utils.plot_model(model_15, to_file='model.png',
                          show_shapes=True, show_layer_names=False, rankdir='TB')
# Out:
# without dropout conv
# without dropout conv
# without dropout conv
# without dropout conv

# %%
#for Private
#training_generator = DataGenerator(train_for, x_col, y_col, batch_size=512, alpha=None, class_w=0.05)

# %%
#for Public
training_generator = DataGenerator(train_for, x_col, y_col, batch_size=512, alpha = None, class_w = 0.1 )
Y_test_2 = np_utils.to_categorical( y_val, 2) # преобразовываем в 2 класса

# %%
initial_learning_rate = 0.005


def lr_step_decay(epoch, lr):
    drop_rate = 0.1
    epochs_drop = 20.0

    return initial_learning_rate * math.pow(drop_rate, math.floor(epoch/epochs_drop))

# %%
# Grid Search 8
gl_p = [False] #0
l2_batch = [ 0.0002] #1
n_ker = [5, 7] #2
n_fil = [ 5, 15] #3
d_hidden = [60, 100] #4
drop_out = [0.25] #5
drop_out_conv = [0.001] #6
reg_dense = [ 0.0002] #7
min_pool = [ 15] #7

# %%
param = itertools.product(gl_p, l2_batch, n_ker, n_fil, d_hidden)

# %% [markdown]
# 0,model_spider8_internal_grid_20_7_5_64_0.0002_200515_2,"(False, 0.0002, 7, 5, 64, 0.25, 0.001, 0.0002, 20)",0.8251300936843902,0.07014745856378353,0.8448725437966713,0.06797556658189371

# %%
#for Private
#param = [(False, 0.0002, 7, 5, 64, 0.25, 0.001, 0.0002, 20)]

# %%
#for Public
#(False, 0.0002, 5, 15, 60, 0.25, 0.001, 0.0002, 15)
param = [(False, 0.0002, 5, 15, 60, 0.25, 0.001, 0.0002, 15, None, None),
         (False, 0.0002, 5, 15, 60, 0.25, 0.001, 0.0002, 15, 0.25, 0)
        ]

# %%
#param = itertools.product(gl_p, l2_batch, n_ker, n_fil, d_hidden)

# %%
inp_shape = X_2_2.shape[1]
inp_shape
# Out:
# 128

# %%
VERBOSE = 2
BATCH_SIZE = 512
NB_EPOCH = 150
#class_weighting = {0:0.05 , 1:1}

#Public
class_weighting = {0:0.1 , 1:1}

result_all_8 = pd.DataFrame()
result_all_8['name_model'] = None
result_all_8['params'] = None
result_all_8['val_GINI'] = None
result_all_8['val_APS'] = None
result_all_8['test_GINI'] = None
result_all_8['test_APS'] = None
j = 0

for p in param:
    print('=====================================================================================================')
    print(inp_shape, X_2_2.shape, p)
    
    model_grid = spider_model_8block(reg = p[1], reg_dense = p[7], n_features = inp_shape, n_pool = 2, n_kernel = p[2], 
                              n_filters = p[3], n_strides = 1, classes = 2, 
                              hidden = p[4] , drop_out = p[5],
                 padding_pool = 'valid' , gl_pool_max = p[0], min_pool = p[8], str_pool = None, 
                                     drop_out_conv=p[9], drop_out_rate=p[10])
    
    model_grid.compile(loss='categorical_crossentropy', 
                 optimizer=tf.keras.optimizers.Adam(learning_rate=0.003),
              metrics=['accuracy', tf.keras.metrics.AUC(), tf.keras.metrics.Precision(),tf.keras.metrics.Recall()])
    
    history_XX = model_grid.fit_generator(generator=training_generator,  #training_aug,
                    validation_data= (X_2_2, Y_test_2) , #Y_test_2 = np_utils.to_categorical( y_val, 2) 
                                     epochs=NB_EPOCH, verbose=VERBOSE, class_weight=class_weighting,
                                     callbacks=[_time , EarlyStopping(monitor='val_loss', patience=20),
                                               Metrics(valid_data=(X_2_2, Y_test_2))])
    
    res_model_ = pd.DataFrame(history_XX.history, columns = history_XX.history.keys())
    dd = str(200000 + datetime.now().month*100 + datetime.now().day) + '_' + str(datetime.now().hour)
    name_m = 'model_spider8_internal_' +str(p[9]) + '_' + str(p[10]) + 't' + str(p[8]) + '_' + str(p[2]) + '_' + str(p[3]) + '_' + str(p[4]) + '_' + str(p[7]) + '_' + str(dd)
    
    model_grid.save( name_m + '.h5')
    res_model_.to_csv(name_m + '.csv')
    
    predict_class_val = model_grid.predict(X_2_2)
    APS = metrics.average_precision_score(y_val, predict_class_val[:,1])
    GINI = 2*(metrics.roc_auc_score(y_val , predict_class_val[:,1])) - 1

    predict_class_test = model_grid.predict(X_3_2)
    APS_t = metrics.average_precision_score(y_test, predict_class_test[:,1])
    GINI_t = 2*(metrics.roc_auc_score(y_test, predict_class_test[:,1])) - 1
    
    result_all_8.at[j , 'name_model'] = name_m
    result_all_8.at[j ,'params'] = str(p)
    result_all_8.at[j ,'val_GINI'] = GINI
    result_all_8.at[j ,'val_APS'] = APS
    result_all_8.at[j ,'test_GINI'] = GINI_t
    result_all_8.at[j ,'test_APS'] = APS_t
    
    result_all_8.to_csv('china_grid_result_all_8_test_dropconv_.csv')
    j += 1
    print(name_m, 'valid_for_train: ', GINI, APS, '| test: ', GINI_t, APS_t)
# Out:
# =====================================================================================================
# 128 (99001, 128) (False, 0.0002, 5, 15, 60, 0.25, 0.001, 0.0002, 15, None, None)
# without dropout conv
# without dropout conv
# without dropout conv
# without dropout conv
# train_begin | time:  07.06.2021 11:57:57
# Epoch 1/150
# epoch_end | time:  07.06.2021 12:32:16
#  — val_aps:  0.453282 — val_a: 0.972215
# 1547/1547 - 2082s - loss: 0.0443 - accuracy: 0.9542 - auc_4: 0.9881 - precision_4: 0.9542 - recall_4: 0.9542 - val_loss: 0.0441 - val_accuracy: 0.9871 - val_auc_4: 0.9982 - val_precision_4: 0.9871 - val_recall_4: 0.9871
# Epoch 2/150
# epoch_end | time:  07.06.2021 13:06:01
#  — val_aps:  0.502915 — val_a: 0.975713
# 1547/1547 - 2023s - loss: 0.0174 - accuracy: 0.9760 - auc_4: 0.9936 - precision_4: 0.9760 - recall_4: 0.9760 - val_loss: 0.0812 - val_accuracy: 0.9786 - val_auc_4: 0.9936 - val_precision_4: 0.9786 - val_recall_4: 0.9786
# Epoch 3/150
# epoch_end | time:  07.06.2021 13:40:12
#  — val_aps:  0.503998 — val_a: 0.974661
# 1547/1547 - 2049s - loss: 0.0150 - accuracy: 0.9788 - auc_4: 0.9951 - precision_4: 0.9788 - recall_4: 0.9788 - val_loss: 0.0794 - val_accuracy: 0.9827 - val_auc_4: 0.9961 - val_precision_4: 0.9827 - val_recall_4: 0.9827
# Epoch 4/150
# epoch_end | time:  07.06.2021 14:16:26
#  — val_aps:  0.511963 — val_a: 0.970784
# 1547/1547 - 2185s - loss: 0.0138 - accuracy: 0.9803 - auc_4: 0.9959 - precision_4: 0.9803 - recall_4: 0.9803 - val_loss: 0.1839 - val_accuracy: 0.9370 - val_auc_4: 0.9775 - val_precision_4: 0.9370 - val_recall_4: 0.9370
# Epoch 5/150
# epoch_end | time:  07.06.2021 14:58:08
#  — val_aps:  0.490206 — val_a: 0.971697
# 1547/1547 - 2498s - loss: 0.0130 - accuracy: 0.9809 - auc_4: 0.9963 - precision_4: 0.9809 - recall_4: 0.9809 - val_loss: 0.0661 - val_accuracy: 0.9813 - val_auc_4: 0.9963 - val_precision_4: 0.9813 - val_recall_4: 0.9813
# Epoch 6/150
# epoch_end | time:  07.06.2021 15:36:41
#  — val_aps:  0.503338 — val_a: 0.969693
# 1547/1547 - 2312s - loss: 0.0124 - accuracy: 0.9815 - auc_4: 0.9967 - precision_4: 0.9815 - recall_4: 0.9815 - val_loss: 0.0426 - val_accuracy: 0.9873 - val_auc_4: 0.9980 - val_precision_4: 0.9873 - val_recall_4: 0.9873
# Epoch 7/150
# epoch_end | time:  07.06.2021 16:36:37
#  — val_aps:  0.468865 — val_a: 0.970167
# 1547/1547 - 3601s - loss: 0.0117 - accuracy: 0.9824 - auc_4: 0.9971 - precision_4: 0.9824 - recall_4: 0.9824 - val_loss: 0.1350 - val_accuracy: 0.9608 - val_auc_4: 0.9885 - val_precision_4: 0.9608 - val_recall_4: 0.9608
# Epoch 8/150
# epoch_end | time:  07.06.2021 17:49:21
#  — val_aps:  0.510925 — val_a: 0.975044
# 1547/1547 - 4364s - loss: 0.0113 - accuracy: 0.9826 - auc_4: 0.9974 - precision_4: 0.9826 - recall_4: 0.9826 - val_loss: 0.0579 - val_accuracy: 0.9809 - val_auc_4: 0.9970 - val_precision_4: 0.9809 - val_recall_4: 0.9809
# Epoch 9/150
# epoch_end | time:  07.06.2021 18:57:36
#  — val_aps:  0.493533 — val_a: 0.972815
# 1547/1547 - 4093s - loss: 0.0108 - accuracy: 0.9831 - auc_4: 0.9976 - precision_4: 0.9831 - recall_4: 0.9831 - val_loss: 0.0740 - val_accuracy: 0.9823 - val_auc_4: 0.9945 - val_precision_4: 0.9823 - val_recall_4: 0.9823
# Epoch 10/150
# epoch_end | time:  07.06.2021 20:05:49
#  — val_aps:  0.425243 — val_a: 0.969825
# 1547/1547 - 4085s - loss: 0.0103 - accuracy: 0.9837 - auc_4: 0.9978 - precision_4: 0.9837 - recall_4: 0.9837 - val_loss: 0.0899 - val_accuracy: 0.9721 - val_auc_4: 0.9944 - val_precision_4: 0.9721 - val_recall_4: 0.9721
# Epoch 11/150
# epoch_end | time:  07.06.2021 21:06:40
#  — val_aps:  0.496795 — val_a: 0.973119
# 1547/1547 - 3640s - loss: 0.0102 - accuracy: 0.9842 - auc_4: 0.9978 - precision_4: 0.9842 - recall_4: 0.9842 - val_loss: 0.0818 - val_accuracy: 0.9712 - val_auc_4: 0.9954 - val_precision_4: 0.9712 - val_recall_4: 0.9712
# Epoch 12/150
# epoch_end | time:  07.06.2021 21:50:11
#  — val_aps:  0.501862 — val_a: 0.969123
# 1547/1547 - 2606s - loss: 0.0098 - accuracy: 0.9845 - auc_4: 0.9980 - precision_4: 0.9845 - recall_4: 0.9845 - val_loss: 0.0399 - val_accuracy: 0.9886 - val_auc_4: 0.9978 - val_precision_4: 0.9886 - val_recall_4: 0.9886
# Epoch 13/150
# epoch_end | time:  07.06.2021 22:34:03
#  — val_aps:  0.503489 — val_a: 0.967243
# 1547/1547 - 2632s - loss: 0.0098 - accuracy: 0.9847 - auc_4: 0.9979 - precision_4: 0.9847 - recall_4: 0.9847 - val_loss: 0.0390 - val_accuracy: 0.9867 - val_auc_4: 0.9983 - val_precision_4: 0.9867 - val_recall_4: 0.9867
# Epoch 14/150
# epoch_end | time:  07.06.2021 23:17:59
#  — val_aps:  0.515392 — val_a: 0.973455
# 1547/1547 - 2634s - loss: 0.0095 - accuracy: 0.9848 - auc_4: 0.9982 - precision_4: 0.9848 - recall_4: 0.9848 - val_loss: 0.0548 - val_accuracy: 0.9813 - val_auc_4: 0.9973 - val_precision_4: 0.9813 - val_recall_4: 0.9813
# Epoch 15/150
# epoch_end | time:  08.06.2021 00:01:44
#  — val_aps:  0.499968 — val_a: 0.970284
# 1547/1547 - 2622s - loss: 0.0093 - accuracy: 0.9855 - auc_4: 0.9982 - precision_4: 0.9855 - recall_4: 0.9855 - val_loss: 0.0611 - val_accuracy: 0.9840 - val_auc_4: 0.9966 - val_precision_4: 0.9840 - val_recall_4: 0.9840
# Epoch 16/150
# epoch_end | time:  08.06.2021 00:47:45
#  — val_aps:  0.521016 — val_a: 0.971990
# 1547/1547 - 2761s - loss: 0.0092 - accuracy: 0.9854 - auc_4: 0.9983 - precision_4: 0.9854 - recall_4: 0.9854 - val_loss: 0.0558 - val_accuracy: 0.9786 - val_auc_4: 0.9978 - val_precision_4: 0.9786 - val_recall_4: 0.9786
# Epoch 17/150
# epoch_end | time:  08.06.2021 01:32:56
#  — val_aps:  0.448727 — val_a: 0.963355
# 1547/1547 - 2709s - loss: 0.0090 - accuracy: 0.9855 - auc_4: 0.9984 - precision_4: 0.9855 - recall_4: 0.9855 - val_loss: 0.0558 - val_accuracy: 0.9838 - val_auc_4: 0.9966 - val_precision_4: 0.9838 - val_recall_4: 0.9838
# Epoch 18/150
# epoch_end | time:  08.06.2021 02:14:54
#  — val_aps:  0.512936 — val_a: 0.971720
# 1547/1547 - 2515s - loss: 0.0089 - accuracy: 0.9857 - auc_4: 0.9983 - precision_4: 0.9857 - recall_4: 0.9857 - val_loss: 0.0549 - val_accuracy: 0.9832 - val_auc_4: 0.9972 - val_precision_4: 0.9832 - val_recall_4: 0.9832
# Epoch 19/150
# epoch_end | time:  08.06.2021 02:58:15
#  — val_aps:  0.507415 — val_a: 0.969424
# 1547/1547 - 2599s - loss: 0.0087 - accuracy: 0.9862 - auc_4: 0.9984 - precision_4: 0.9862 - recall_4: 0.9862 - val_loss: 0.0377 - val_accuracy: 0.9891 - val_auc_4: 0.9982 - val_precision_4: 0.9891 - val_recall_4: 0.9891
# Epoch 20/150
# epoch_end | time:  08.06.2021 03:41:34
#  — val_aps:  0.483169 — val_a: 0.966784
# 1547/1547 - 2598s - loss: 0.0086 - accuracy: 0.9861 - auc_4: 0.9984 - precision_4: 0.9861 - recall_4: 0.9861 - val_loss: 0.0542 - val_accuracy: 0.9853 - val_auc_4: 0.9969 - val_precision_4: 0.9853 - val_recall_4: 0.9853
# Epoch 21/150
# epoch_end | time:  08.06.2021 04:24:29
#  — val_aps:  0.489754 — val_a: 0.967474
# 1547/1547 - 2572s - loss: 0.0085 - accuracy: 0.9865 - auc_4: 0.9985 - precision_4: 0.9865 - recall_4: 0.9865 - val_loss: 0.0556 - val_accuracy: 0.9826 - val_auc_4: 0.9973 - val_precision_4: 0.9826 - val_recall_4: 0.9826
# Epoch 22/150
# epoch_end | time:  08.06.2021 05:07:55
#  — val_aps:  0.448338 — val_a: 0.965750
# 1547/1547 - 2608s - loss: 0.0084 - accuracy: 0.9865 - auc_4: 0.9985 - precision_4: 0.9865 - recall_4: 0.9865 - val_loss: 0.1014 - val_accuracy: 0.9657 - val_auc_4: 0.9934 - val_precision_4: 0.9657 - val_recall_4: 0.9657
# Epoch 23/150
# epoch_end | time:  08.06.2021 05:52:53
#  — val_aps:  0.503149 — val_a: 0.970771
# 1547/1547 - 2698s - loss: 0.0082 - accuracy: 0.9869 - auc_4: 0.9986 - precision_4: 0.9869 - recall_4: 0.9869 - val_loss: 0.1284 - val_accuracy: 0.9451 - val_auc_4: 0.9902 - val_precision_4: 0.9451 - val_recall_4: 0.9451
# Epoch 24/150
# epoch_end | time:  08.06.2021 06:38:18
#  — val_aps:  0.465040 — val_a: 0.964645
# 1547/1547 - 2722s - loss: 0.0082 - accuracy: 0.9868 - auc_4: 0.9986 - precision_4: 0.9868 - recall_4: 0.9868 - val_loss: 0.1037 - val_accuracy: 0.9611 - val_auc_4: 0.9931 - val_precision_4: 0.9611 - val_recall_4: 0.9611
# Epoch 25/150
# epoch_end | time:  08.06.2021 07:22:44
#  — val_aps:  0.475923 — val_a: 0.961435
# 1547/1547 - 2665s - loss: 0.0081 - accuracy: 0.9870 - auc_4: 0.9986 - precision_4: 0.9870 - recall_4: 0.9870 - val_loss: 0.0864 - val_accuracy: 0.9773 - val_auc_4: 0.9938 - val_precision_4: 0.9773 - val_recall_4: 0.9773
# Epoch 26/150
# epoch_end | time:  08.06.2021 08:07:53
#  — val_aps:  0.465609 — val_a: 0.957158
# 1547/1547 - 2707s - loss: 0.0081 - accuracy: 0.9868 - auc_4: 0.9986 - precision_4: 0.9868 - recall_4: 0.9868 - val_loss: 0.0514 - val_accuracy: 0.9876 - val_auc_4: 0.9965 - val_precision_4: 0.9876 - val_recall_4: 0.9876
# Epoch 27/150
# epoch_end | time:  08.06.2021 08:53:18
#  — val_aps:  0.488050 — val_a: 0.963557
# 1547/1547 - 2722s - loss: 0.0078 - accuracy: 0.9875 - auc_4: 0.9987 - precision_4: 0.9875 - recall_4: 0.9875 - val_loss: 0.0616 - val_accuracy: 0.9830 - val_auc_4: 0.9961 - val_precision_4: 0.9830 - val_recall_4: 0.9830
# Epoch 28/150
# epoch_end | time:  08.06.2021 09:38:16
#  — val_aps:  0.474332 — val_a: 0.963216
# 1547/1547 - 2695s - loss: 0.0079 - accuracy: 0.9874 - auc_4: 0.9987 - precision_4: 0.9874 - recall_4: 0.9874 - val_loss: 0.0631 - val_accuracy: 0.9782 - val_auc_4: 0.9971 - val_precision_4: 0.9782 - val_recall_4: 0.9782
# Epoch 29/150
# epoch_end | time:  08.06.2021 10:24:07
#  — val_aps:  0.508436 — val_a: 0.970157
# 1547/1547 - 2751s - loss: 0.0077 - accuracy: 0.9877 - auc_4: 0.9988 - precision_4: 0.9877 - recall_4: 0.9877 - val_loss: 0.0708 - val_accuracy: 0.9737 - val_auc_4: 0.9964 - val_precision_4: 0.9737 - val_recall_4: 0.9737
# Epoch 30/150
# epoch_end | time:  08.06.2021 11:12:43
#  — val_aps:  0.452082 — val_a: 0.959551
# 1547/1547 - 2925s - loss: 0.0078 - accuracy: 0.9880 - auc_4: 0.9987 - precision_4: 0.9880 - recall_4: 0.9880 - val_loss: 0.0910 - val_accuracy: 0.9717 - val_auc_4: 0.9938 - val_precision_4: 0.9717 - val_recall_4: 0.9717
# Epoch 31/150
# epoch_end | time:  08.06.2021 11:59:19
#  — val_aps:  0.462816 — val_a: 0.965068
# 1547/1547 - 2780s - loss: 0.0077 - accuracy: 0.9878 - auc_4: 0.9987 - precision_4: 0.9878 - recall_4: 0.9878 - val_loss: 0.1276 - val_accuracy: 0.9580 - val_auc_4: 0.9902 - val_precision_4: 0.9580 - val_recall_4: 0.9580
# Epoch 32/150
# epoch_end | time:  08.06.2021 12:42:07
#  — val_aps:  0.447286 — val_a: 0.950789
# 1547/1547 - 2564s - loss: 0.0075 - accuracy: 0.9880 - auc_4: 0.9988 - precision_4: 0.9880 - recall_4: 0.9880 - val_loss: 0.0487 - val_accuracy: 0.9891 - val_auc_4: 0.9965 - val_precision_4: 0.9891 - val_recall_4: 0.9891
# Epoch 33/150
# epoch_end | time:  08.06.2021 13:19:21
#  — val_aps:  0.501621 — val_a: 0.949710
# 1547/1547 - 2232s - loss: 0.0075 - accuracy: 0.9879 - auc_4: 0.9988 - precision_4: 0.9879 - recall_4: 0.9879 - val_loss: 0.0502 - val_accuracy: 0.9899 - val_auc_4: 0.9960 - val_precision_4: 0.9899 - val_recall_4: 0.9899
# Epoch 34/150
# epoch_end | time:  08.06.2021 13:56:58
#  — val_aps:  0.500267 — val_a: 0.969623
# 1547/1547 - 2264s - loss: 0.0075 - accuracy: 0.9881 - auc_4: 0.9988 - precision_4: 0.9881 - recall_4: 0.9881 - val_loss: 0.1158 - val_accuracy: 0.9545 - val_auc_4: 0.9917 - val_precision_4: 0.9545 - val_recall_4: 0.9545
# Epoch 35/150
# epoch_end | time:  08.06.2021 14:40:04
#  — val_aps:  0.514545 — val_a: 0.967714
# 1547/1547 - 2583s - loss: 0.0074 - accuracy: 0.9880 - auc_4: 0.9989 - precision_4: 0.9880 - recall_4: 0.9880 - val_loss: 0.0752 - val_accuracy: 0.9778 - val_auc_4: 0.9953 - val_precision_4: 0.9778 - val_recall_4: 0.9778
# Epoch 36/150
# epoch_end | time:  08.06.2021 15:23:20
#  — val_aps:  0.512511 — val_a: 0.970208
# 1547/1547 - 2596s - loss: 0.0074 - accuracy: 0.9881 - auc_4: 0.9989 - precision_4: 0.9881 - recall_4: 0.9881 - val_loss: 0.0731 - val_accuracy: 0.9750 - val_auc_4: 0.9958 - val_precision_4: 0.9750 - val_recall_4: 0.9750
# Epoch 37/150
# epoch_end | time:  08.06.2021 16:04:11
#  — val_aps:  0.468161 — val_a: 0.953819
# 1547/1547 - 2443s - loss: 0.0074 - accuracy: 0.9882 - auc_4: 0.9988 - precision_4: 0.9882 - recall_4: 0.9882 - val_loss: 0.0462 - val_accuracy: 0.9890 - val_auc_4: 0.9968 - val_precision_4: 0.9890 - val_recall_4: 0.9890
# Epoch 38/150
# epoch_end | time:  08.06.2021 16:44:14
#  — val_aps:  0.491905 — val_a: 0.958104
# 1547/1547 - 2400s - loss: 0.0071 - accuracy: 0.9886 - auc_4: 0.9990 - precision_4: 0.9886 - recall_4: 0.9886 - val_loss: 0.0502 - val_accuracy: 0.9899 - val_auc_4: 0.9964 - val_precision_4: 0.9899 - val_recall_4: 0.9899
# Epoch 39/150
# epoch_end | time:  08.06.2021 17:28:43
#  — val_aps:  0.445331 — val_a: 0.963988
# 1547/1547 - 2671s - loss: 0.0073 - accuracy: 0.9884 - auc_4: 0.9989 - precision_4: 0.9884 - recall_4: 0.9884 - val_loss: 0.1200 - val_accuracy: 0.9622 - val_auc_4: 0.9914 - val_precision_4: 0.9622 - val_recall_4: 0.9622
# model_spider8_internal_None_Nonet15_5_15_60_0.0002_200608_17 valid_for_train:  0.9279755762955244 0.44533068145570154 | test:  0.9266447785911758 0.4044263786950835
# =====================================================================================================
# 128 (99001, 128) (False, 0.0002, 5, 15, 60, 0.25, 0.001, 0.0002, 15, 0.25, 0)
# 1 0.25
# 2 0.25
# 3 0.25
# 4 0.25
# train_begin | time:  08.06.2021 17:30:43
# Epoch 1/150
# epoch_end | time:  08.06.2021 18:13:33
#  — val_aps:  0.439414 — val_a: 0.967978
# 1547/1547 - 2596s - loss: 0.0448 - accuracy: 0.9523 - auc_5: 0.9869 - precision_5: 0.9523 - recall_5: 0.9523 - val_loss: 0.0532 - val_accuracy: 0.9889 - val_auc_5: 0.9989 - val_precision_5: 0.9889 - val_recall_5: 0.9889
# Epoch 2/150
# epoch_end | time:  08.06.2021 18:54:01
#  — val_aps:  0.438359 — val_a: 0.963609
# 1547/1547 - 2424s - loss: 0.0185 - accuracy: 0.9739 - auc_5: 0.9929 - precision_5: 0.9739 - recall_5: 0.9739 - val_loss: 0.3224 - val_accuracy: 0.8794 - val_auc_5: 0.9393 - val_precision_5: 0.8794 - val_recall_5: 0.8794
# Epoch 3/150
# epoch_end | time:  08.06.2021 19:33:57
#  — val_aps:  0.474760 — val_a: 0.972173
# 1547/1547 - 2395s - loss: 0.0164 - accuracy: 0.9771 - auc_5: 0.9944 - precision_5: 0.9771 - recall_5: 0.9771 - val_loss: 0.1128 - val_accuracy: 0.9751 - val_auc_5: 0.9924 - val_precision_5: 0.9751 - val_recall_5: 0.9751
# Epoch 4/150
# epoch_end | time:  08.06.2021 20:13:11
#  — val_aps:  0.451728 — val_a: 0.971550
# 1547/1547 - 2350s - loss: 0.0151 - accuracy: 0.9786 - auc_5: 0.9952 - precision_5: 0.9786 - recall_5: 0.9786 - val_loss: 0.0599 - val_accuracy: 0.9840 - val_auc_5: 0.9962 - val_precision_5: 0.9840 - val_recall_5: 0.9840
# Epoch 5/150
# epoch_end | time:  08.06.2021 20:52:22
#  — val_aps:  0.501047 — val_a: 0.975825
# 1547/1547 - 2350s - loss: 0.0143 - accuracy: 0.9798 - auc_5: 0.9958 - precision_5: 0.9798 - recall_5: 0.9798 - val_loss: 0.0640 - val_accuracy: 0.9811 - val_auc_5: 0.9972 - val_precision_5: 0.9811 - val_recall_5: 0.9811
# Epoch 6/150
# epoch_end | time:  08.06.2021 21:31:28
#  — val_aps:  0.476918 — val_a: 0.973414
# 1547/1547 - 2344s - loss: 0.0136 - accuracy: 0.9803 - auc_5: 0.9962 - precision_5: 0.9803 - recall_5: 0.9803 - val_loss: 0.0692 - val_accuracy: 0.9801 - val_auc_5: 0.9958 - val_precision_5: 0.9801 - val_recall_5: 0.9801
# Epoch 7/150
# epoch_end | time:  08.06.2021 22:10:34
#  — val_aps:  0.488746 — val_a: 0.974293
# 1547/1547 - 2345s - loss: 0.0132 - accuracy: 0.9803 - auc_5: 0.9965 - precision_5: 0.9803 - recall_5: 0.9803 - val_loss: 0.0740 - val_accuracy: 0.9768 - val_auc_5: 0.9962 - val_precision_5: 0.9768 - val_recall_5: 0.9768
# Epoch 8/150
# epoch_end | time:  08.06.2021 22:55:56
#  — val_aps:  0.470793 — val_a: 0.973264
# 1547/1547 - 2733s - loss: 0.0127 - accuracy: 0.9806 - auc_5: 0.9968 - precision_5: 0.9806 - recall_5: 0.9806 - val_loss: 0.1283 - val_accuracy: 0.9595 - val_auc_5: 0.9898 - val_precision_5: 0.9595 - val_recall_5: 0.9595
# Epoch 9/150
# epoch_end | time:  09.06.2021 00:04:58
#  — val_aps:  0.508552 — val_a: 0.974313
# 1547/1547 - 4132s - loss: 0.0124 - accuracy: 0.9810 - auc_5: 0.9969 - precision_5: 0.9810 - recall_5: 0.9810 - val_loss: 0.0594 - val_accuracy: 0.9829 - val_auc_5: 0.9963 - val_precision_5: 0.9829 - val_recall_5: 0.9829
# Epoch 10/150
# epoch_end | time:  09.06.2021 00:54:21
#  — val_aps:  0.466173 — val_a: 0.973752
# 1547/1547 - 2959s - loss: 0.0121 - accuracy: 0.9813 - auc_5: 0.9971 - precision_5: 0.9813 - recall_5: 0.9813 - val_loss: 0.0638 - val_accuracy: 0.9788 - val_auc_5: 0.9969 - val_precision_5: 0.9788 - val_recall_5: 0.9788
# Epoch 11/150
# epoch_end | time:  09.06.2021 01:44:13
#  — val_aps:  0.495717 — val_a: 0.972964
# 1547/1547 - 2991s - loss: 0.0117 - accuracy: 0.9820 - auc_5: 0.9973 - precision_5: 0.9820 - recall_5: 0.9820 - val_loss: 0.0479 - val_accuracy: 0.9848 - val_auc_5: 0.9977 - val_precision_5: 0.9848 - val_recall_5: 0.9848
# Epoch 12/150
# epoch_end | time:  09.06.2021 02:33:53
#  — val_aps:  0.469451 — val_a: 0.974200
# 1547/1547 - 2980s - loss: 0.0117 - accuracy: 0.9817 - auc_5: 0.9973 - precision_5: 0.9817 - recall_5: 0.9817 - val_loss: 0.0568 - val_accuracy: 0.9830 - val_auc_5: 0.9974 - val_precision_5: 0.9830 - val_recall_5: 0.9830
# Epoch 13/150
# epoch_end | time:  09.06.2021 03:23:12
#  — val_aps:  0.455019 — val_a: 0.969482
# 1547/1547 - 2953s - loss: 0.0113 - accuracy: 0.9825 - auc_5: 0.9975 - precision_5: 0.9825 - recall_5: 0.9825 - val_loss: 0.0488 - val_accuracy: 0.9859 - val_auc_5: 0.9974 - val_precision_5: 0.9859 - val_recall_5: 0.9859
# Epoch 14/150
# epoch_end | time:  09.06.2021 04:12:48
#  — val_aps:  0.432127 — val_a: 0.953351
# 1547/1547 - 2975s - loss: 0.0111 - accuracy: 0.9826 - auc_5: 0.9976 - precision_5: 0.9826 - recall_5: 0.9826 - val_loss: 0.0481 - val_accuracy: 0.9894 - val_auc_5: 0.9964 - val_precision_5: 0.9894 - val_recall_5: 0.9894
# Epoch 15/150
# epoch_end | time:  09.06.2021 05:02:11
#  — val_aps:  0.531115 — val_a: 0.972760
# 1547/1547 - 2960s - loss: 0.0110 - accuracy: 0.9824 - auc_5: 0.9976 - precision_5: 0.9824 - recall_5: 0.9824 - val_loss: 0.0632 - val_accuracy: 0.9780 - val_auc_5: 0.9970 - val_precision_5: 0.9780 - val_recall_5: 0.9780
# Epoch 16/150
# epoch_end | time:  09.06.2021 05:51:21
#  — val_aps:  0.499335 — val_a: 0.972559
# 1547/1547 - 2949s - loss: 0.0107 - accuracy: 0.9829 - auc_5: 0.9978 - precision_5: 0.9829 - recall_5: 0.9829 - val_loss: 0.0827 - val_accuracy: 0.9688 - val_auc_5: 0.9956 - val_precision_5: 0.9688 - val_recall_5: 0.9688
# Epoch 17/150
# epoch_end | time:  09.06.2021 06:40:15
#  — val_aps:  0.460875 — val_a: 0.971366
# 1547/1547 - 2932s - loss: 0.0106 - accuracy: 0.9833 - auc_5: 0.9978 - precision_5: 0.9833 - recall_5: 0.9833 - val_loss: 0.1489 - val_accuracy: 0.9612 - val_auc_5: 0.9871 - val_precision_5: 0.9612 - val_recall_5: 0.9612
# Epoch 18/150
# epoch_end | time:  09.06.2021 07:29:05
#  — val_aps:  0.488236 — val_a: 0.970307
# 1547/1547 - 2927s - loss: 0.0106 - accuracy: 0.9833 - auc_5: 0.9978 - precision_5: 0.9833 - recall_5: 0.9833 - val_loss: 0.0667 - val_accuracy: 0.9806 - val_auc_5: 0.9966 - val_precision_5: 0.9806 - val_recall_5: 0.9806
# Epoch 19/150
# epoch_end | time:  09.06.2021 08:17:45
#  — val_aps:  0.458309 — val_a: 0.969350
# 1547/1547 - 2918s - loss: 0.0104 - accuracy: 0.9831 - auc_5: 0.9979 - precision_5: 0.9831 - recall_5: 0.9831 - val_loss: 0.0446 - val_accuracy: 0.9866 - val_auc_5: 0.9982 - val_precision_5: 0.9866 - val_recall_5: 0.9866
# Epoch 20/150
# epoch_end | time:  09.06.2021 09:07:37
#  — val_aps:  0.529430 — val_a: 0.971433
# 1547/1547 - 2992s - loss: 0.0102 - accuracy: 0.9835 - auc_5: 0.9979 - precision_5: 0.9835 - recall_5: 0.9835 - val_loss: 0.0416 - val_accuracy: 0.9867 - val_auc_5: 0.9980 - val_precision_5: 0.9867 - val_recall_5: 0.9867
# Epoch 21/150
# epoch_end | time:  09.06.2021 09:57:50
#  — val_aps:  0.481101 — val_a: 0.974289
# 1547/1547 - 3007s - loss: 0.0101 - accuracy: 0.9838 - auc_5: 0.9980 - precision_5: 0.9838 - recall_5: 0.9838 - val_loss: 0.1097 - val_accuracy: 0.9582 - val_auc_5: 0.9923 - val_precision_5: 0.9582 - val_recall_5: 0.9582
# Epoch 22/150
# epoch_end | time:  09.06.2021 10:51:51
#  — val_aps:  0.503645 — val_a: 0.970655
# 1547/1547 - 3242s - loss: 0.0100 - accuracy: 0.9838 - auc_5: 0.9981 - precision_5: 0.9838 - recall_5: 0.9838 - val_loss: 0.0541 - val_accuracy: 0.9812 - val_auc_5: 0.9978 - val_precision_5: 0.9812 - val_recall_5: 0.9812
# Epoch 23/150
# epoch_end | time:  09.06.2021 11:48:53
#  — val_aps:  0.508584 — val_a: 0.972362
# 1547/1547 - 3419s - loss: 0.0098 - accuracy: 0.9840 - auc_5: 0.9981 - precision_5: 0.9840 - recall_5: 0.9840 - val_loss: 0.0517 - val_accuracy: 0.9819 - val_auc_5: 0.9978 - val_precision_5: 0.9819 - val_recall_5: 0.9819
# Epoch 24/150
# epoch_end | time:  09.06.2021 12:53:43
#  — val_aps:  0.492031 — val_a: 0.970894
# 1547/1547 - 3889s - loss: 0.0098 - accuracy: 0.9842 - auc_5: 0.9981 - precision_5: 0.9842 - recall_5: 0.9842 - val_loss: 0.0409 - val_accuracy: 0.9877 - val_auc_5: 0.9981 - val_precision_5: 0.9877 - val_recall_5: 0.9877
# Epoch 25/150
# epoch_end | time:  09.06.2021 13:55:26
#  — val_aps:  0.507323 — val_a: 0.970727
# 1547/1547 - 3715s - loss: 0.0097 - accuracy: 0.9845 - auc_5: 0.9981 - precision_5: 0.9845 - recall_5: 0.9845 - val_loss: 0.0524 - val_accuracy: 0.9842 - val_auc_5: 0.9973 - val_precision_5: 0.9842 - val_recall_5: 0.9842
# Epoch 26/150
# epoch_end | time:  09.06.2021 14:57:08
#  — val_aps:  0.508556 — val_a: 0.968634
# 1547/1547 - 3695s - loss: 0.0096 - accuracy: 0.9842 - auc_5: 0.9982 - precision_5: 0.9842 - recall_5: 0.9842 - val_loss: 0.0491 - val_accuracy: 0.9863 - val_auc_5: 0.9973 - val_precision_5: 0.9863 - val_recall_5: 0.9863
# Epoch 27/150
# epoch_end | time:  09.06.2021 16:01:05
#  — val_aps:  0.510123 — val_a: 0.968911
# 1547/1547 - 3834s - loss: 0.0095 - accuracy: 0.9847 - auc_5: 0.9982 - precision_5: 0.9847 - recall_5: 0.9847 - val_loss: 0.0374 - val_accuracy: 0.9896 - val_auc_5: 0.9980 - val_precision_5: 0.9896 - val_recall_5: 0.9896
# Epoch 28/150
# epoch_end | time:  09.06.2021 17:05:42
#  — val_aps:  0.479281 — val_a: 0.967119
# 1547/1547 - 3873s - loss: 0.0096 - accuracy: 0.9845 - auc_5: 0.9982 - precision_5: 0.9845 - recall_5: 0.9845 - val_loss: 0.0421 - val_accuracy: 0.9868 - val_auc_5: 0.9979 - val_precision_5: 0.9868 - val_recall_5: 0.9868
# Epoch 29/150
# epoch_end | time:  09.06.2021 18:06:18
#  — val_aps:  0.515358 — val_a: 0.970725
# 1547/1547 - 3630s - loss: 0.0094 - accuracy: 0.9849 - auc_5: 0.9983 - precision_5: 0.9849 - recall_5: 0.9849 - val_loss: 0.0614 - val_accuracy: 0.9802 - val_auc_5: 0.9969 - val_precision_5: 0.9802 - val_recall_5: 0.9802
# Epoch 30/150
# epoch_end | time:  09.06.2021 19:06:40
#  — val_aps:  0.497009 — val_a: 0.968493
# 1547/1547 - 3620s - loss: 0.0092 - accuracy: 0.9850 - auc_5: 0.9983 - precision_5: 0.9850 - recall_5: 0.9850 - val_loss: 0.0528 - val_accuracy: 0.9837 - val_auc_5: 0.9973 - val_precision_5: 0.9837 - val_recall_5: 0.9837
# Epoch 31/150
# epoch_end | time:  09.06.2021 20:09:22
#  — val_aps:  0.485915 — val_a: 0.965433
# 1547/1547 - 3760s - loss: 0.0092 - accuracy: 0.9851 - auc_5: 0.9983 - precision_5: 0.9851 - recall_5: 0.9851 - val_loss: 0.0438 - val_accuracy: 0.9890 - val_auc_5: 0.9973 - val_precision_5: 0.9890 - val_recall_5: 0.9890
# Epoch 32/150
# epoch_end | time:  09.06.2021 21:06:31
#  — val_aps:  0.513562 — val_a: 0.969306
# 1547/1547 - 3428s - loss: 0.0092 - accuracy: 0.9850 - auc_5: 0.9984 - precision_5: 0.9850 - recall_5: 0.9850 - val_loss: 0.0726 - val_accuracy: 0.9779 - val_auc_5: 0.9957 - val_precision_5: 0.9779 - val_recall_5: 0.9779
# Epoch 33/150
# epoch_end | time:  09.06.2021 22:03:32
#  — val_aps:  0.426537 — val_a: 0.963659
# 1547/1547 - 3416s - loss: 0.0090 - accuracy: 0.9857 - auc_5: 0.9984 - precision_5: 0.9857 - recall_5: 0.9857 - val_loss: 0.1474 - val_accuracy: 0.9470 - val_auc_5: 0.9869 - val_precision_5: 0.9470 - val_recall_5: 0.9470
# Epoch 34/150
# epoch_end | time:  09.06.2021 23:00:40
#  — val_aps:  0.307338 — val_a: 0.959270
# 1547/1547 - 3427s - loss: 0.0092 - accuracy: 0.9850 - auc_5: 0.9984 - precision_5: 0.9850 - recall_5: 0.9850 - val_loss: 0.1674 - val_accuracy: 0.9625 - val_auc_5: 0.9861 - val_precision_5: 0.9625 - val_recall_5: 0.9625
# Epoch 35/150
# epoch_end | time:  09.06.2021 23:57:15
#  — val_aps:  0.494880 — val_a: 0.968755
# 1547/1547 - 3394s - loss: 0.0089 - accuracy: 0.9856 - auc_5: 0.9984 - precision_5: 0.9856 - recall_5: 0.9856 - val_loss: 0.0670 - val_accuracy: 0.9809 - val_auc_5: 0.9959 - val_precision_5: 0.9809 - val_recall_5: 0.9809
# Epoch 36/150
# epoch_end | time:  10.06.2021 00:53:16
#  — val_aps:  0.501121 — val_a: 0.970118
# 1547/1547 - 3366s - loss: 0.0089 - accuracy: 0.9856 - auc_5: 0.9984 - precision_5: 0.9856 - recall_5: 0.9856 - val_loss: 0.0414 - val_accuracy: 0.9866 - val_auc_5: 0.9982 - val_precision_5: 0.9866 - val_recall_5: 0.9866
# Epoch 37/150
# epoch_end | time:  10.06.2021 01:44:49
#  — val_aps:  0.435975 — val_a: 0.967445
# 1547/1547 - 3080s - loss: 0.0089 - accuracy: 0.9855 - auc_5: 0.9984 - precision_5: 0.9855 - recall_5: 0.9855 - val_loss: 0.1469 - val_accuracy: 0.9534 - val_auc_5: 0.9880 - val_precision_5: 0.9534 - val_recall_5: 0.9534
# Epoch 38/150
# epoch_end | time:  10.06.2021 02:37:02
#  — val_aps:  0.505115 — val_a: 0.969139
# 1547/1547 - 3131s - loss: 0.0088 - accuracy: 0.9857 - auc_5: 0.9985 - precision_5: 0.9857 - recall_5: 0.9857 - val_loss: 0.0403 - val_accuracy: 0.9877 - val_auc_5: 0.9982 - val_precision_5: 0.9877 - val_recall_5: 0.9877
# Epoch 39/150
# epoch_end | time:  10.06.2021 03:29:35
#  — val_aps:  0.523518 — val_a: 0.968931
# 1547/1547 - 3151s - loss: 0.0087 - accuracy: 0.9857 - auc_5: 0.9985 - precision_5: 0.9857 - recall_5: 0.9857 - val_loss: 0.0641 - val_accuracy: 0.9798 - val_auc_5: 0.9966 - val_precision_5: 0.9798 - val_recall_5: 0.9798
# Epoch 40/150
# epoch_end | time:  10.06.2021 04:21:57
#  — val_aps:  0.494432 — val_a: 0.970834
# 1547/1547 - 3139s - loss: 0.0089 - accuracy: 0.9857 - auc_5: 0.9985 - precision_5: 0.9857 - recall_5: 0.9857 - val_loss: 0.0495 - val_accuracy: 0.9843 - val_auc_5: 0.9975 - val_precision_5: 0.9843 - val_recall_5: 0.9843
# Epoch 41/150
# epoch_end | time:  10.06.2021 05:14:07
#  — val_aps:  0.471304 — val_a: 0.964680
# 1547/1547 - 3127s - loss: 0.0087 - accuracy: 0.9859 - auc_5: 0.9985 - precision_5: 0.9859 - recall_5: 0.9859 - val_loss: 0.0490 - val_accuracy: 0.9872 - val_auc_5: 0.9971 - val_precision_5: 0.9872 - val_recall_5: 0.9872
# Epoch 42/150
# epoch_end | time:  10.06.2021 06:06:55
#  — val_aps:  0.485063 — val_a: 0.968783
# 1547/1547 - 3165s - loss: 0.0085 - accuracy: 0.9861 - auc_5: 0.9986 - precision_5: 0.9861 - recall_5: 0.9861 - val_loss: 0.0670 - val_accuracy: 0.9815 - val_auc_5: 0.9959 - val_precision_5: 0.9815 - val_recall_5: 0.9815
# Epoch 43/150
# epoch_end | time:  10.06.2021 06:59:04
#  — val_aps:  0.498901 — val_a: 0.968249
# 1547/1547 - 3128s - loss: 0.0086 - accuracy: 0.9860 - auc_5: 0.9985 - precision_5: 0.9860 - recall_5: 0.9860 - val_loss: 0.0520 - val_accuracy: 0.9842 - val_auc_5: 0.9975 - val_precision_5: 0.9842 - val_recall_5: 0.9842
# Epoch 44/150
# epoch_end | time:  10.06.2021 07:51:17
#  — val_aps:  0.511817 — val_a: 0.970642
# 1547/1547 - 3131s - loss: 0.0086 - accuracy: 0.9862 - auc_5: 0.9985 - precision_5: 0.9862 - recall_5: 0.9862 - val_loss: 0.0739 - val_accuracy: 0.9775 - val_auc_5: 0.9963 - val_precision_5: 0.9775 - val_recall_5: 0.9775
# Epoch 45/150
# epoch_end | time:  10.06.2021 08:43:09
#  — val_aps:  0.500532 — val_a: 0.968905
# 1547/1547 - 3110s - loss: 0.0086 - accuracy: 0.9863 - auc_5: 0.9985 - precision_5: 0.9863 - recall_5: 0.9863 - val_loss: 0.0472 - val_accuracy: 0.9858 - val_auc_5: 0.9975 - val_precision_5: 0.9858 - val_recall_5: 0.9858
# Epoch 46/150
# epoch_end | time:  10.06.2021 09:38:09
#  — val_aps:  0.505703 — val_a: 0.969939
# 1547/1547 - 3298s - loss: 0.0085 - accuracy: 0.9864 - auc_5: 0.9986 - precision_5: 0.9864 - recall_5: 0.9864 - val_loss: 0.0745 - val_accuracy: 0.9784 - val_auc_5: 0.9954 - val_precision_5: 0.9784 - val_recall_5: 0.9784
# Epoch 47/150
# epoch_end | time:  10.06.2021 10:35:46
#  — val_aps:  0.489337 — val_a: 0.969149
# 1547/1547 - 3458s - loss: 0.0085 - accuracy: 0.9861 - auc_5: 0.9986 - precision_5: 0.9861 - recall_5: 0.9861 - val_loss: 0.0443 - val_accuracy: 0.9870 - val_auc_5: 0.9978 - val_precision_5: 0.9870 - val_recall_5: 0.9870
# model_spider8_internal_0.25_0t15_5_15_60_0.0002_200610_10 valid_for_train:  0.938297650491307 0.4893373871275455 | test:  0.9373021563506421 0.46753637269407344

# %%
predict_class_val = model_grid.predict(X_2_2)
APS = metrics.average_precision_score(y_test, predict_class_val[:, 1])
GINI = 2*(metrics.roc_auc_score(y_test, predict_class_val[:, 1])) - 1

predict_class_test = model_grid.predict(X_3_2)
APS_t = metrics.average_precision_score(y_val, predict_class_test[:, 1])
GINI_t = 2*(metrics.roc_auc_score(y_val, predict_class_test[:, 1])) - 1

# %%
result_all_8.at[j , 'name_model'] = name_m
result_all_8.at[j ,'params'] = str(p)
result_all_8.at[j ,'val_GINI'] = GINI
result_all_8.at[j ,'val_APS'] = APS
result_all_8.at[j ,'test_GINI'] = GINI_t
result_all_8.at[j ,'test_APS'] = APS_t
    
result_all_8.to_csv('internal_grid_result_all_8_wo_dropconv_.csv')
result_all_8
# Out:
#                                           name_model  \
# 0  model_spider8_internal_grid_wo_dropconv_20_7_5...
#
#                                               params  val_GINI    val_APS  \
# 0  (False, 0.0002, 7, 5, 64, 0.25, 0.001, 0.0002,...  0.827039  0.0545976
#
#   test_GINI   test_APS
# 0  0.842407  0.0464484

# %% [markdown]
# ## SpiderNet-8

# %%
def spider_model_8block(l2_conv = None, reg = 1E-5 , reg_dense = 1E-5,
                 _bias = True,  n_features = 163, n_pool = 2, n_kernel = 5, n_filters = 5, n_strides = 1,
                 classes = 2, hidden = 64 , drop_out = 0.25, drop_out_conv = 0.001, drop_out_rate = 4 ,
                 padding_pool = 'valid' ,
                gl_pool_max = False,
                       min_pool = 12, str_pool = None):
    
    if reg == None:
        l2_batch_gamma = None 
        l2_batch_betta = None
    else:
        l2_batch_gamma = l2(reg)
        l2_batch_betta =l2(reg)
    
    if reg_dense == None:
        kernel_regularizer = None
    else:
        kernel_regularizer = l2(reg)   
    
    
    x = Input(shape=(  n_features, 1))
    n = -2 # для 6 - n = 0, для 8 = -2
    y = Conv1D(filters=n_filters, kernel_size=n_kernel, strides=n_strides, padding='same', 
           use_bias=_bias, kernel_regularizer=l2_conv)(x) 

    y = BatchNormalization(gamma_regularizer=l2_batch_gamma ,beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)
#y = Dropout(rate=drop_rate)(y)

    y = max_pool(min_pool, n_pool, padding_pool, str_pool, y) ##
    shortcut1_2 = max_pool(min_pool, n_pool, padding_pool, str_pool, y)## поправить
    shortcut1_3 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut1_2)##
    shortcut1_4 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut1_3)##
    
    shortcut1_5 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut1_4)
    shortcut1_6 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut1_5) #*
    shortcut1_7 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut1_6) #*

    # второй spider-block
    y = Conv1D(filters=n_filters*2, kernel_size=n_kernel, strides=n_strides, padding='same',
              use_bias=_bias, kernel_regularizer=l2_conv)(y) 
    y = BatchNormalization(gamma_regularizer=l2_batch_gamma ,beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)

    y = max_pool(min_pool, n_pool, padding_pool, str_pool, y) ##
    shortcut2_3 = max_pool(min_pool, n_pool, padding_pool, str_pool, y)##
    shortcut2_4 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut2_3)##
    
    shortcut2_5 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut2_4)
    shortcut2_6 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut2_5)
    shortcut2_7 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut2_6)


    y= Concatenate(axis=-1)([shortcut1_2, y])
    n = n+1

    # третий spider-block
    y = Conv1D(filters=n_filters*(3 + 1), kernel_size=n_kernel, strides=n_strides, padding='same',
              use_bias=_bias, kernel_regularizer=l2_conv)(y) 
    y = BatchNormalization(gamma_regularizer=l2_batch_gamma ,beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)

    y = max_pool(min_pool, n_pool, padding_pool, str_pool, y) ##
    shortcut3_4 = max_pool(min_pool, n_pool, padding_pool, str_pool, y)##
    
    shortcut3_5 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut3_4)##
    shortcut3_6 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut3_5)##
    shortcut3_7 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut3_6)##

    y= Concatenate(axis=-1)([shortcut2_3, shortcut1_3, y])
    
    n = n+1
    # четвертый spider-block
    y = Conv1D(filters=n_filters*(4 + 1), kernel_size=n_kernel, strides=n_strides, padding='same',
              use_bias=_bias, kernel_regularizer=l2_conv)(y) 
    y = BatchNormalization(gamma_regularizer=l2_batch_gamma ,beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)

    y = max_pool(min_pool, n_pool, padding_pool, str_pool, y) ##
    shortcut4_5 = max_pool(min_pool, n_pool, padding_pool, str_pool, y)##
    shortcut4_6 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut4_5)##
    shortcut4_7 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut4_6)##

    y= Concatenate(axis=-1)([shortcut3_4, shortcut2_4, shortcut1_4, y])
    n = n+1
    if drop_out_rate is not None:
        y = Dropout(drop_out_conv*(n**drop_out_rate))(y)
        print(n, drop_out_conv*(n**drop_out_rate))
    elif drop_out_rate == 0:
        y = Dropout(drop_out_conv)(y)
        print(n, drop_out_conv)
    else:
        print('without dropout conv')

    # пятый spider-block
    y = Conv1D(filters=n_filters*(5 + 1), kernel_size=n_kernel, strides=n_strides, padding='same',
              use_bias=_bias, kernel_regularizer=l2_conv)(y) 
    y = BatchNormalization(gamma_regularizer=l2_batch_gamma ,beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)

    y = max_pool(min_pool, n_pool, padding_pool, str_pool, y) ##
    shortcut5_6 = max_pool(min_pool, n_pool, padding_pool, str_pool, y)
    shortcut5_7 = max_pool(min_pool, n_pool, padding_pool, str_pool, shortcut5_6)    
    
    
    y= Concatenate(axis=-1)([shortcut4_5, shortcut3_5, shortcut2_5, shortcut1_5, y])
    n = n+1
    if drop_out_rate is not None:
        y = Dropout(drop_out_conv*(n**drop_out_rate))(y)
        print(n, drop_out_conv*(n**drop_out_rate))
    elif drop_out_rate == 0:
        y = Dropout(drop_out_conv)(y)
        print(n, drop_out_conv)
    else:
        print('without dropout conv')

    # шестой spider-block
    y = Conv1D(filters=n_filters*(6 + 1), kernel_size=n_kernel, strides=n_strides, padding='same',
              use_bias=_bias, kernel_regularizer=l2_conv)(y) 
    y = BatchNormalization(gamma_regularizer=l2_batch_gamma ,beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)
    
    y = max_pool(min_pool, n_pool, padding_pool, str_pool, y) ##
    shortcut6_7 = max_pool(min_pool, n_pool, padding_pool, str_pool, y)
    
    y= Concatenate(axis=-1)([shortcut5_6, shortcut4_6, shortcut3_6, shortcut2_6, shortcut1_6, y])
    n = n+1
    if drop_out_rate is not None:
        y = Dropout(drop_out_conv*(n**drop_out_rate))(y)
        print(n, drop_out_conv*(n**drop_out_rate))
    elif drop_out_rate == 0:
        y = Dropout(drop_out_conv)(y)
        print(n, drop_out_conv)
    else:
        print('without dropout conv')
    
    
    # седьмой блок
    y = Conv1D(filters=n_filters*(7 + 1), kernel_size=n_kernel, strides=n_strides, padding='same',
              use_bias=_bias, kernel_regularizer=l2_conv)(y) 
    y = BatchNormalization(gamma_regularizer=l2_batch_gamma ,beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)
    
    y = max_pool(min_pool, n_pool, padding_pool, str_pool, y) ##
    
    y= Concatenate(axis=-1)([shortcut6_7, shortcut5_7, shortcut4_7, shortcut3_7, shortcut2_7, shortcut1_7, y])
    n = n+1
    if drop_out_rate is not None:
        y = Dropout(drop_out_conv*(n**drop_out_rate))(y)
        print(n, drop_out_conv*(n**drop_out_rate))
    elif drop_out_rate == 0:
        y = Dropout(drop_out_conv)(y)
        print(n, drop_out_conv)
    else:
        print('without dropout conv')
            
    
     # восьмой блок
    y = Conv1D(filters=n_filters*(8 + 1), kernel_size=n_kernel, strides=n_strides, padding='same',
              use_bias=_bias, kernel_regularizer=l2_conv)(y) 
    y = BatchNormalization(gamma_regularizer=l2_batch_gamma ,beta_regularizer=l2_batch_betta)(y)
    y = ReLU()(y)
    
    y = max_pool(min_pool, n_pool, padding_pool, str_pool, y) ##
    
    if gl_pool_max:
        z = GlobalMaxPooling1D()(y)
        
    else:
        z = GlobalAveragePooling1D()(y)
    #z = Flatten()(y) #сглаживание, пример использования - https://stackoverflow.com/questions/43237124/what-is-the-role-of-flatten-in-keras
    z = Dense(hidden, activation='relu', kernel_regularizer = kernel_regularizer)(z)
    z = Dropout(drop_out)(z)
    z = Dense(hidden, activation='relu', kernel_regularizer = kernel_regularizer)(z)
    z = Dropout(drop_out)(z)
    predictions = Dense(classes, activation='softmax')(z)

    #model = Sequential()
    model_15 = Model(inputs=x, outputs=predictions)
    
    return model_15

# %%
VERBOSE = 2
BATCH_SIZE = 512
NB_EPOCH = 150
class_weighting = {0:0.05 , 1:1}

j = 1

for p in param:
    print('=====================================================================================================')
    print(inp_shape, X_2_2.shape, p)
    
    model_grid = spider_model_8block(reg = p[1], reg_dense = p[7], n_features = inp_shape, n_pool = 2, n_kernel = p[2], 
                              n_filters = p[3], n_strides = 1, classes = 2, 
                              hidden = p[4] , drop_out = p[5],
                 padding_pool = 'valid' , gl_pool_max = p[0], min_pool = p[8], str_pool = None, 
                                     drop_out_conv=0.25, drop_out_rate=0)
    
    model_grid.compile(loss='categorical_crossentropy', 
                 optimizer=tf.keras.optimizers.Adam(learning_rate=0.003),
              metrics=['accuracy', tf.keras.metrics.AUC(), tf.keras.metrics.Precision(),tf.keras.metrics.Recall()])
    
    history_XX = model_grid.fit_generator(generator=training_generator,  #training_aug,
                    validation_data= (X_2_2, Y_test_2) , #Y_test_2 = np_utils.to_categorical( y_val, 2) 
                                     epochs=NB_EPOCH, verbose=VERBOSE, class_weight=class_weighting,
                                     callbacks=[_time , EarlyStopping(monitor='val_loss', patience=20),
                                               Metrics(valid_data=(X_2_2, Y_test_2))])
    
    res_model_ = pd.DataFrame(history_XX.history, columns = history_XX.history.keys())
    dd = str(200000 + datetime.now().month*100 + datetime.now().day) + '_' + str(datetime.now().hour)
    name_m = 'model_spider8_internal_grid_dropconst_0.25' + str(p[8]) + '_' + str(p[2]) + '_' + str(p[3]) + '_' + str(p[4]) + '_' + str(p[7]) + '_' + str(dd)
    
    model_grid.save( name_m + '.h5')
    res_model_.to_csv(name_m + '.csv')
    
    predict_class_val = model_grid.predict(X_2_2)
    APS = metrics.average_precision_score(y_test, predict_class_val[:, 1])
    GINI = 2*(metrics.roc_auc_score(y_test, predict_class_val[:, 1])) - 1

    predict_class_test = model_grid.predict(X_3_2)
    APS_t = metrics.average_precision_score(y_val, predict_class_test[:, 1])
    GINI_t = 2*(metrics.roc_auc_score(y_val, predict_class_test[:, 1])) - 1
    
    result_all_8.at[j , 'name_model'] = name_m
    result_all_8.at[j ,'params'] = str(p)
    result_all_8.at[j ,'val_GINI'] = GINI
    result_all_8.at[j ,'val_APS'] = APS
    result_all_8.at[j ,'test_GINI'] = GINI_t
    result_all_8.at[j ,'test_APS'] = APS_t
    
    result_all_8.to_csv('internal_grid_result_all_8_wo_dropconv_.csv')
    j += 1
    print(name_m, 'valid_for_train: ', GINI, APS, '| test: ', GINI_t, APS_t)
# Out:
# =====================================================================================================
# 163 (185400, 163) (False, 0.0002, 7, 5, 64, 0.25, 0.001, 0.0002, 20)
# 1 0.25
# 2 0.25
# 3 0.25
# 4 0.25
# train_begin | time:  03.06.2021 19:44:33
# Epoch 1/150
# epoch_end | time:  03.06.2021 20:04:03
#  — val_aps:  0.051093 — val_a: 0.888787
# 2945/2945 - 1206s - loss: 0.0153 - accuracy: 0.9726 - auc_3: 0.9940 - precision_3: 0.9726 - recall_3: 0.9726 - val_loss: 0.7373 - val_accuracy: 0.7957 - val_auc_3: 0.8301 - val_precision_3: 0.7957 - val_recall_3: 0.7957
# Epoch 2/150
# epoch_end | time:  03.06.2021 20:24:10
#  — val_aps:  0.058759 — val_a: 0.939364
# 2945/2945 - 1203s - loss: 0.0074 - accuracy: 0.9860 - auc_3: 0.9973 - precision_3: 0.9860 - recall_3: 0.9860 - val_loss: 0.0840 - val_accuracy: 0.9773 - val_auc_3: 0.9967 - val_precision_3: 0.9773 - val_recall_3: 0.9773
# Epoch 3/150
# epoch_end | time:  03.06.2021 20:44:03
#  — val_aps:  0.072053 — val_a: 0.934020
# 2945/2945 - 1194s - loss: 0.0068 - accuracy: 0.9868 - auc_3: 0.9978 - precision_3: 0.9868 - recall_3: 0.9868 - val_loss: 0.0465 - val_accuracy: 0.9910 - val_auc_3: 0.9994 - val_precision_3: 0.9910 - val_recall_3: 0.9910
# Epoch 4/150
# epoch_end | time:  03.06.2021 21:04:08
#  — val_aps:  0.063201 — val_a: 0.932888
# 2945/2945 - 1211s - loss: 0.0064 - accuracy: 0.9870 - auc_3: 0.9982 - precision_3: 0.9870 - recall_3: 0.9870 - val_loss: 0.0502 - val_accuracy: 0.9875 - val_auc_3: 0.9976 - val_precision_3: 0.9875 - val_recall_3: 0.9875
# Epoch 5/150
# epoch_end | time:  03.06.2021 21:24:04
#  — val_aps:  0.080508 — val_a: 0.942741
# 2945/2945 - 1186s - loss: 0.0062 - accuracy: 0.9873 - auc_3: 0.9983 - precision_3: 0.9873 - recall_3: 0.9873 - val_loss: 0.0514 - val_accuracy: 0.9797 - val_auc_3: 0.9985 - val_precision_3: 0.9797 - val_recall_3: 0.9797
# Epoch 6/150
# epoch_end | time:  03.06.2021 21:43:48
#  — val_aps:  0.065839 — val_a: 0.933162
# 2945/2945 - 1185s - loss: 0.0060 - accuracy: 0.9879 - auc_3: 0.9985 - precision_3: 0.9879 - recall_3: 0.9879 - val_loss: 0.0256 - val_accuracy: 0.9934 - val_auc_3: 0.9992 - val_precision_3: 0.9934 - val_recall_3: 0.9934
# Epoch 7/150
# epoch_end | time:  03.06.2021 22:03:36
#  — val_aps:  0.059406 — val_a: 0.932925
# 2945/2945 - 1185s - loss: 0.0058 - accuracy: 0.9881 - auc_3: 0.9985 - precision_3: 0.9881 - recall_3: 0.9881 - val_loss: 0.0321 - val_accuracy: 0.9893 - val_auc_3: 0.9989 - val_precision_3: 0.9893 - val_recall_3: 0.9893
# Epoch 8/150
# epoch_end | time:  03.06.2021 22:23:14
#  — val_aps:  0.080873 — val_a: 0.932833
# 2945/2945 - 1180s - loss: 0.0057 - accuracy: 0.9880 - auc_3: 0.9985 - precision_3: 0.9880 - recall_3: 0.9880 - val_loss: 0.0191 - val_accuracy: 0.9959 - val_auc_3: 0.9989 - val_precision_3: 0.9959 - val_recall_3: 0.9959
# Epoch 9/150
# epoch_end | time:  03.06.2021 22:43:06
#  — val_aps:  0.071585 — val_a: 0.930712
# 2945/2945 - 1193s - loss: 0.0055 - accuracy: 0.9884 - auc_3: 0.9986 - precision_3: 0.9884 - recall_3: 0.9884 - val_loss: 0.0568 - val_accuracy: 0.9861 - val_auc_3: 0.9983 - val_precision_3: 0.9861 - val_recall_3: 0.9861
# Epoch 10/150
# epoch_end | time:  03.06.2021 23:02:54
#  — val_aps:  0.070957 — val_a: 0.934642
# 2945/2945 - 1185s - loss: 0.0054 - accuracy: 0.9884 - auc_3: 0.9987 - precision_3: 0.9884 - recall_3: 0.9884 - val_loss: 0.0248 - val_accuracy: 0.9943 - val_auc_3: 0.9994 - val_precision_3: 0.9943 - val_recall_3: 0.9943
# Epoch 11/150
# epoch_end | time:  03.06.2021 23:22:46
#  — val_aps:  0.079334 — val_a: 0.940298
# 2945/2945 - 1189s - loss: 0.0054 - accuracy: 0.9884 - auc_3: 0.9987 - precision_3: 0.9884 - recall_3: 0.9884 - val_loss: 0.0284 - val_accuracy: 0.9914 - val_auc_3: 0.9992 - val_precision_3: 0.9914 - val_recall_3: 0.9914
# Epoch 12/150
# epoch_end | time:  03.06.2021 23:42:26
#  — val_aps:  0.060546 — val_a: 0.935474
# 2945/2945 - 1179s - loss: 0.0053 - accuracy: 0.9888 - auc_3: 0.9987 - precision_3: 0.9888 - recall_3: 0.9888 - val_loss: 0.0482 - val_accuracy: 0.9869 - val_auc_3: 0.9975 - val_precision_3: 0.9869 - val_recall_3: 0.9869
# Epoch 13/150
# epoch_end | time:  04.06.2021 00:00:59
#  — val_aps:  0.071502 — val_a: 0.928843
# 2945/2945 - 1110s - loss: 0.0052 - accuracy: 0.9886 - auc_3: 0.9988 - precision_3: 0.9886 - recall_3: 0.9886 - val_loss: 0.0231 - val_accuracy: 0.9944 - val_auc_3: 0.9994 - val_precision_3: 0.9944 - val_recall_3: 0.9944
# Epoch 14/150
# epoch_end | time:  04.06.2021 00:19:30
#  — val_aps:  0.052288 — val_a: 0.931408
# 2945/2945 - 1111s - loss: 0.0052 - accuracy: 0.9891 - auc_3: 0.9988 - precision_3: 0.9891 - recall_3: 0.9891 - val_loss: 0.1490 - val_accuracy: 0.9460 - val_auc_3: 0.9868 - val_precision_3: 0.9460 - val_recall_3: 0.9460
# Epoch 15/150
# epoch_end | time:  04.06.2021 00:38:05
#  — val_aps:  0.068980 — val_a: 0.942067
# 2945/2945 - 1113s - loss: 0.0052 - accuracy: 0.9889 - auc_3: 0.9988 - precision_3: 0.9889 - recall_3: 0.9889 - val_loss: 0.0272 - val_accuracy: 0.9919 - val_auc_3: 0.9990 - val_precision_3: 0.9919 - val_recall_3: 0.9919
# Epoch 16/150
# epoch_end | time:  04.06.2021 00:56:45
#  — val_aps:  0.077911 — val_a: 0.941878
# 2945/2945 - 1120s - loss: 0.0051 - accuracy: 0.9888 - auc_3: 0.9988 - precision_3: 0.9888 - recall_3: 0.9888 - val_loss: 0.0244 - val_accuracy: 0.9943 - val_auc_3: 0.9993 - val_precision_3: 0.9943 - val_recall_3: 0.9943
# Epoch 17/150
# epoch_end | time:  04.06.2021 01:15:11
#  — val_aps:  0.061173 — val_a: 0.932714
# 2945/2945 - 1109s - loss: 0.0050 - accuracy: 0.9892 - auc_3: 0.9989 - precision_3: 0.9892 - recall_3: 0.9892 - val_loss: 0.0697 - val_accuracy: 0.9818 - val_auc_3: 0.9972 - val_precision_3: 0.9818 - val_recall_3: 0.9818
# Epoch 18/150
# epoch_end | time:  04.06.2021 01:33:47
#  — val_aps:  0.057611 — val_a: 0.919215
# 2945/2945 - 1110s - loss: 0.0049 - accuracy: 0.9889 - auc_3: 0.9989 - precision_3: 0.9889 - recall_3: 0.9889 - val_loss: 0.0256 - val_accuracy: 0.9934 - val_auc_3: 0.9985 - val_precision_3: 0.9934 - val_recall_3: 0.9934
# Epoch 19/150
# epoch_end | time:  04.06.2021 01:52:18
#  — val_aps:  0.079450 — val_a: 0.944889
# 2945/2945 - 1112s - loss: 0.0049 - accuracy: 0.9892 - auc_3: 0.9989 - precision_3: 0.9892 - recall_3: 0.9892 - val_loss: 0.0269 - val_accuracy: 0.9918 - val_auc_3: 0.9992 - val_precision_3: 0.9918 - val_recall_3: 0.9918
# Epoch 20/150
# epoch_end | time:  04.06.2021 02:11:00
#  — val_aps:  0.065169 — val_a: 0.937218
# 2945/2945 - 1121s - loss: 0.0049 - accuracy: 0.9890 - auc_3: 0.9989 - precision_3: 0.9890 - recall_3: 0.9890 - val_loss: 0.0311 - val_accuracy: 0.9935 - val_auc_3: 0.9993 - val_precision_3: 0.9935 - val_recall_3: 0.9935
# Epoch 21/150
# epoch_end | time:  04.06.2021 02:29:44
#  — val_aps:  0.073644 — val_a: 0.927843
# 2945/2945 - 1124s - loss: 0.0048 - accuracy: 0.9892 - auc_3: 0.9989 - precision_3: 0.9892 - recall_3: 0.9892 - val_loss: 0.0187 - val_accuracy: 0.9968 - val_auc_3: 0.9993 - val_precision_3: 0.9968 - val_recall_3: 0.9968
# Epoch 22/150
# epoch_end | time:  04.06.2021 02:48:24
#  — val_aps:  0.071150 — val_a: 0.933057
# 2945/2945 - 1119s - loss: 0.0048 - accuracy: 0.9892 - auc_3: 0.9989 - precision_3: 0.9892 - recall_3: 0.9892 - val_loss: 0.0184 - val_accuracy: 0.9963 - val_auc_3: 0.9989 - val_precision_3: 0.9963 - val_recall_3: 0.9963
# Epoch 23/150
# epoch_end | time:  04.06.2021 03:07:22
#  — val_aps:  0.065354 — val_a: 0.930489
# 2945/2945 - 1138s - loss: 0.0047 - accuracy: 0.9891 - auc_3: 0.9989 - precision_3: 0.9891 - recall_3: 0.9891 - val_loss: 0.0244 - val_accuracy: 0.9929 - val_auc_3: 0.9991 - val_precision_3: 0.9929 - val_recall_3: 0.9929
# Epoch 24/150
# epoch_end | time:  04.06.2021 03:26:21
#  — val_aps:  0.061689 — val_a: 0.926627
# 2945/2945 - 1139s - loss: 0.0048 - accuracy: 0.9892 - auc_3: 0.9989 - precision_3: 0.9892 - recall_3: 0.9892 - val_loss: 0.0397 - val_accuracy: 0.9869 - val_auc_3: 0.9980 - val_precision_3: 0.9869 - val_recall_3: 0.9869
# Epoch 25/150
# epoch_end | time:  04.06.2021 03:44:54
#  — val_aps:  0.068950 — val_a: 0.933492
# 2945/2945 - 1113s - loss: 0.0047 - accuracy: 0.9890 - auc_3: 0.9989 - precision_3: 0.9890 - recall_3: 0.9890 - val_loss: 0.0232 - val_accuracy: 0.9950 - val_auc_3: 0.9992 - val_precision_3: 0.9950 - val_recall_3: 0.9950
# Epoch 26/150
# epoch_end | time:  04.06.2021 04:04:05
#  — val_aps:  0.083234 — val_a: 0.944289
# 2945/2945 - 1150s - loss: 0.0047 - accuracy: 0.9890 - auc_3: 0.9989 - precision_3: 0.9890 - recall_3: 0.9890 - val_loss: 0.0398 - val_accuracy: 0.9872 - val_auc_3: 0.9990 - val_precision_3: 0.9872 - val_recall_3: 0.9872
# Epoch 27/150
# epoch_end | time:  04.06.2021 04:23:03
#  — val_aps:  0.080816 — val_a: 0.931811
# 2945/2945 - 1138s - loss: 0.0046 - accuracy: 0.9893 - auc_3: 0.9990 - precision_3: 0.9893 - recall_3: 0.9893 - val_loss: 0.0220 - val_accuracy: 0.9958 - val_auc_3: 0.9994 - val_precision_3: 0.9958 - val_recall_3: 0.9958
# Epoch 28/150
# epoch_end | time:  04.06.2021 04:41:51
#  — val_aps:  0.074009 — val_a: 0.904590
# 2945/2945 - 1127s - loss: 0.0047 - accuracy: 0.9893 - auc_3: 0.9989 - precision_3: 0.9893 - recall_3: 0.9893 - val_loss: 0.0187 - val_accuracy: 0.9969 - val_auc_3: 0.9983 - val_precision_3: 0.9969 - val_recall_3: 0.9969
# Epoch 29/150
# epoch_end | time:  04.06.2021 05:00:44
#  — val_aps:  0.080105 — val_a: 0.930924
# 2945/2945 - 1133s - loss: 0.0046 - accuracy: 0.9895 - auc_3: 0.9990 - precision_3: 0.9895 - recall_3: 0.9895 - val_loss: 0.0200 - val_accuracy: 0.9949 - val_auc_3: 0.9990 - val_precision_3: 0.9949 - val_recall_3: 0.9949
# Epoch 30/150
# epoch_end | time:  04.06.2021 05:19:37
#  — val_aps:  0.079824 — val_a: 0.943352
# 2945/2945 - 1135s - loss: 0.0046 - accuracy: 0.9893 - auc_3: 0.9990 - precision_3: 0.9893 - recall_3: 0.9893 - val_loss: 0.0449 - val_accuracy: 0.9903 - val_auc_3: 0.9992 - val_precision_3: 0.9903 - val_recall_3: 0.9903
# Epoch 31/150
# epoch_end | time:  04.06.2021 05:38:34
#  — val_aps:  0.073784 — val_a: 0.937313
# 2945/2945 - 1135s - loss: 0.0045 - accuracy: 0.9891 - auc_3: 0.9990 - precision_3: 0.9891 - recall_3: 0.9891 - val_loss: 0.0481 - val_accuracy: 0.9821 - val_auc_3: 0.9981 - val_precision_3: 0.9821 - val_recall_3: 0.9821
# Epoch 32/150
# epoch_end | time:  04.06.2021 05:57:31
#  — val_aps:  0.057532 — val_a: 0.926921
# 2945/2945 - 1137s - loss: 0.0045 - accuracy: 0.9894 - auc_3: 0.9990 - precision_3: 0.9894 - recall_3: 0.9894 - val_loss: 0.0344 - val_accuracy: 0.9901 - val_auc_3: 0.9981 - val_precision_3: 0.9901 - val_recall_3: 0.9901
# Epoch 33/150
# epoch_end | time:  04.06.2021 06:16:23
#  — val_aps:  0.061659 — val_a: 0.934853
# 2945/2945 - 1131s - loss: 0.0045 - accuracy: 0.9892 - auc_3: 0.9990 - precision_3: 0.9892 - recall_3: 0.9892 - val_loss: 0.0588 - val_accuracy: 0.9838 - val_auc_3: 0.9979 - val_precision_3: 0.9838 - val_recall_3: 0.9838
# Epoch 34/150
# epoch_end | time:  04.06.2021 06:35:20
#  — val_aps:  0.044969 — val_a: 0.915913
# 2945/2945 - 1137s - loss: 0.0045 - accuracy: 0.9891 - auc_3: 0.9990 - precision_3: 0.9891 - recall_3: 0.9891 - val_loss: 0.0940 - val_accuracy: 0.9708 - val_auc_3: 0.9935 - val_precision_3: 0.9708 - val_recall_3: 0.9708
# Epoch 35/150
# epoch_end | time:  04.06.2021 06:54:05
#  — val_aps:  0.057729 — val_a: 0.926441
# 2945/2945 - 1125s - loss: 0.0045 - accuracy: 0.9890 - auc_3: 0.9990 - precision_3: 0.9890 - recall_3: 0.9890 - val_loss: 0.0218 - val_accuracy: 0.9948 - val_auc_3: 0.9987 - val_precision_3: 0.9948 - val_recall_3: 0.9948
# Epoch 36/150
# epoch_end | time:  04.06.2021 07:13:43
#  — val_aps:  0.081835 — val_a: 0.928365
# 2945/2945 - 1199s - loss: 0.0045 - accuracy: 0.9892 - auc_3: 0.9990 - precision_3: 0.9892 - recall_3: 0.9892 - val_loss: 0.0201 - val_accuracy: 0.9955 - val_auc_3: 0.9986 - val_precision_3: 0.9955 - val_recall_3: 0.9955
# Epoch 37/150
# epoch_end | time:  04.06.2021 07:41:26
#  — val_aps:  0.050498 — val_a: 0.923474
# 2945/2945 - 1668s - loss: 0.0044 - accuracy: 0.9894 - auc_3: 0.9990 - precision_3: 0.9894 - recall_3: 0.9894 - val_loss: 0.0245 - val_accuracy: 0.9942 - val_auc_3: 0.9985 - val_precision_3: 0.9942 - val_recall_3: 0.9942
# Epoch 38/150
# epoch_end | time:  04.06.2021 08:08:19
#  — val_aps:  0.074292 — val_a: 0.927221
# 2945/2945 - 1611s - loss: 0.0044 - accuracy: 0.9891 - auc_3: 0.9990 - precision_3: 0.9891 - recall_3: 0.9891 - val_loss: 0.0267 - val_accuracy: 0.9919 - val_auc_3: 0.9991 - val_precision_3: 0.9919 - val_recall_3: 0.9919
# Epoch 39/150
# epoch_end | time:  04.06.2021 08:35:23
#  — val_aps:  0.057583 — val_a: 0.924895
# 2945/2945 - 1623s - loss: 0.0044 - accuracy: 0.9891 - auc_3: 0.9990 - precision_3: 0.9891 - recall_3: 0.9891 - val_loss: 0.0277 - val_accuracy: 0.9925 - val_auc_3: 0.9988 - val_precision_3: 0.9925 - val_recall_3: 0.9925
# Epoch 40/150
# epoch_end | time:  04.06.2021 09:02:18
#  — val_aps:  0.076032 — val_a: 0.930038
# 2945/2945 - 1612s - loss: 0.0044 - accuracy: 0.9893 - auc_3: 0.9990 - precision_3: 0.9893 - recall_3: 0.9893 - val_loss: 0.0237 - val_accuracy: 0.9950 - val_auc_3: 0.9983 - val_precision_3: 0.9950 - val_recall_3: 0.9950
# Epoch 41/150
# epoch_end | time:  04.06.2021 09:30:09
#  — val_aps:  0.071123 — val_a: 0.930867
# 2945/2945 - 1676s - loss: 0.0044 - accuracy: 0.9895 - auc_3: 0.9990 - precision_3: 0.9895 - recall_3: 0.9895 - val_loss: 0.0252 - val_accuracy: 0.9929 - val_auc_3: 0.9987 - val_precision_3: 0.9929 - val_recall_3: 0.9929
# Epoch 42/150
# epoch_end | time:  04.06.2021 09:57:23
#  — val_aps:  0.056863 — val_a: 0.927449
# 2945/2945 - 1632s - loss: 0.0044 - accuracy: 0.9896 - auc_3: 0.9990 - precision_3: 0.9896 - recall_3: 0.9896 - val_loss: 0.0200 - val_accuracy: 0.9960 - val_auc_3: 0.9989 - val_precision_3: 0.9960 - val_recall_3: 0.9960
# model_spider8_internal_grid_dropconst_0.2520_7_5_64_0.0002_200604_9 valid_for_train:  0.8548978716647357 0.05686334048403198 | test:  0.8236958493135069 0.048575857020453625
